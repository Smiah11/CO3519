# %% [markdown]
# <a href="https://colab.research.google.com/github/Smiah11/CO3519/blob/main/SaeedMiah_CO3519_Assignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import pandas as pd
import numpy as np
import csv
import zipfile
from google.colab import drive
import PIL
from PIL import Image
import tensorflow as tf
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt
from imblearn.over_sampling import RandomOverSampler
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from sklearn.metrics import classification_report

# %% [markdown]
# #Mount Drive to access Data

# %%
#mount google drive
drive.mount('/content/drive',force_remount=True)
#get the path to the data
train_image_path = '/content/drive/My Drive/ISIC_2020_Training_JPEG/train'
train_data_path = '/content/drive/MyDrive/ISIC_2020_Training_GroundTruth_v2.csv'
test_image_path = '/content/drive/My Drive/ISIC_2020_Test_JPEG/ISIC_2020_Test_Input'
test_data_path = '/content/drive/MyDrive/ISIC_2020_Test_Metadata (1).csv'

df = pd.read_csv(train_data_path)
# Out:
# Mounted at /content/drive

# %%
# Function to count the number of images in a directory
def count_images_in_directory(data_dir):
    num_images = sum([len(files) for _, _, files in os.walk(data_dir)])
    return num_images

# Count images in the training and test directories
train_image_count = count_images_in_directory(train_image_path)
test_image_count = count_images_in_directory(test_image_path)

print(f"Number of training images: {train_image_count}")
print(f"Number of test images: {test_image_count}")
# Out:
# Number of training images: 66252
# Number of test images: 10984

# %%
# Create images array, will store 2D array of [image_name, {data}]
images = []

with open(train_data_path) as f:
    reader = csv.reader(f, delimiter=',')
    for row in reader:
        # Skip first row
        if row[0] == "image_name":
            continue

        # Add row to array
        images.append([
            row[0],
            {
                "id": row[1],
                "sex": row[2],
                "age": row[3],
                "anatom_site": row[4],
                "diagnosis": row[5],
                "benign_malignant": row[6],
                "target": row[7]
            }
        ])

# %% [markdown]
# #Pre Process Data
# Remove Duplicates and unknowns then resize

# %%
import pandas as pd

print(f"Initial number of records: {len(df)}")

# Remove duplicate rows based on image_name
df = df.drop_duplicates(subset='image_name')
print(f"Remaining records after removing duplicates: {len(df)}")

# Remove rows with unknown records
df = df[df['diagnosis'] != 'unknown']
print(f"Remaining records after removing unknowns: {len(df)}")
# Out:
# Initial number of records: 33126
# Remaining records after removing duplicates: 33126
# Remaining records after removing unknowns: 6002

# %% [markdown]
# Resize the images and put them in a save

# %%
import os
from PIL import Image

# Define  image path to save resized images
image_output = os.path.join(train_image_path, 'resized')

# Make sure output directory exists
if not os.path.exists(image_output):
    os.makedirs(image_output)

# Define image size
image_size = (224,224)

# Iterate over  dataframe
for index, row in df.iterrows():
    # Construct file paths
    file_name = row['image_name'] + '.jpg'
    input_path = os.path.join(train_image_path, file_name)
    output_path = os.path.join(image_output, file_name)

    # If the image has not been resized yet
    if not os.path.exists(output_path):
        # Open, resize, and save image
        with Image.open(input_path) as img:
            img_resized = img.resize(image_size)
            img_resized.save(output_path)
            print(f"Image {file_name} has been resized and saved to {output_path}")

# %% [markdown]
# #OverSampling (Class Imbalance)

# %%
from sklearn.preprocessing import LabelEncoder

# Create a label encoder object
le = LabelEncoder()

# Apply the label encoder to the benign_malignant column
df['benign_malignant'] = le.fit_transform(df['benign_malignant'])

print(le.classes_)
# Out:
# ['benign' 'malignant']

# %%
# Print the initial class distribution
print('Initial class distribution:\n', df['benign_malignant'].value_counts())
# 0 = benign
# 1 = malignant
# Out:
# Initial class distribution:
#  0    5418
# 1     584
# Name: benign_malignant, dtype: int64

# %% [markdown]
# #Using Naive Random Oversampling to balance the class distribution

# %% [markdown]
# kept filling the dataframe with empties? commented out

# %%
## Separate majority and minority classes
#df_majority = df[df.benign_malignant==0]
#df_minority = df[df.benign_malignant==1]

# Count how many instances are in the majority class
#majority_count = df_majority.shape[0]

# Upsample minority class
#df_minority_upsampled = df_minority.sample(majority_count, replace=True)

# Combine majority class with upsampled minority class
#df_upsampled = pd.concat([df_majority, df_minority_upsampled])

# Print the new class distribution
#print('\nNew class distribution:\n', df_upsampled['benign_malignant'].value_counts())

print(df.head())
# Out:
#       image_name  patient_id   lesion_id     sex  age_approx  \
# 2   ISIC_0052212  IP_2842074  IL_9087444  female        50.0
# 12  ISIC_0076995  IP_2235340  IL_7147389  female        55.0
# 26  ISIC_0084086  IP_4023055  IL_9753248    male        60.0
# 27  ISIC_0084270  IP_2961528  IL_3011969    male        40.0
# 28  ISIC_0084395  IP_0175539  IL_8767924  female        45.0
#
#    anatom_site_general_challenge diagnosis benign_malignant  target
# 2                lower extremity     nevus           benign       0
# 12                         torso     nevus           benign       0
# 26               lower extremity     nevus           benign       0
# 27               lower extremity     nevus           benign       0
# 28                         torso     nevus           benign       0

# %% [markdown]
# # Model Development

# %%
import tensorflow as tf
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout

# Load the pre-trained MobileNetV2 model, excluding its final layer
base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Add a global spatial average pooling layer
x = base_model.output
x = GlobalAveragePooling2D()(x)

# Add a dropout layer for regularisation
x = Dropout(0.5)(x)

# Add a final dense layer for classification
predictions = Dense(1, activation='sigmoid')(x)

# Define the model
model = Model(inputs=base_model.input, outputs=predictions)

# Freeze the base_model
for layer in base_model.layers:
    layer.trainable = False

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Display the model summary
model.summary()
# Out:
# Model: "model_8"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_9 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  Conv1 (Conv2D)                 (None, 112, 112, 32  864         ['input_9[0][0]']
#                                 )
#
#  bn_Conv1 (BatchNormalization)  (None, 112, 112, 32  128         ['Conv1[0][0]']
#                                 )
#
#  Conv1_relu (ReLU)              (None, 112, 112, 32  0           ['bn_Conv1[0][0]']
#                                 )
#
#  expanded_conv_depthwise (Depth  (None, 112, 112, 32  288        ['Conv1_relu[0][0]']
#  wiseConv2D)                    )
#
#  expanded_conv_depthwise_BN (Ba  (None, 112, 112, 32  128        ['expanded_conv_depthwise[0][0]']
#  tchNormalization)              )
#
#  expanded_conv_depthwise_relu (  (None, 112, 112, 32  0          ['expanded_conv_depthwise_BN[0][0
#  ReLU)                          )                                ]']
#
#  expanded_conv_project (Conv2D)  (None, 112, 112, 16  512        ['expanded_conv_depthwise_relu[0]
#                                 )                                [0]']
#
#  expanded_conv_project_BN (Batc  (None, 112, 112, 16  64         ['expanded_conv_project[0][0]']
#  hNormalization)                )
#
#  block_1_expand (Conv2D)        (None, 112, 112, 96  1536        ['expanded_conv_project_BN[0][0]'
#                                 )                                ]
#
#  block_1_expand_BN (BatchNormal  (None, 112, 112, 96  384        ['block_1_expand[0][0]']
#  ization)                       )
#
#  block_1_expand_relu (ReLU)     (None, 112, 112, 96  0           ['block_1_expand_BN[0][0]']
#                                 )
#
#  block_1_pad (ZeroPadding2D)    (None, 113, 113, 96  0           ['block_1_expand_relu[0][0]']
#                                 )
#
#  block_1_depthwise (DepthwiseCo  (None, 56, 56, 96)  864         ['block_1_pad[0][0]']
#  nv2D)
#
#  block_1_depthwise_BN (BatchNor  (None, 56, 56, 96)  384         ['block_1_depthwise[0][0]']
#  malization)
#
#  block_1_depthwise_relu (ReLU)  (None, 56, 56, 96)   0           ['block_1_depthwise_BN[0][0]']
#
#  block_1_project (Conv2D)       (None, 56, 56, 24)   2304        ['block_1_depthwise_relu[0][0]']
#
#  block_1_project_BN (BatchNorma  (None, 56, 56, 24)  96          ['block_1_project[0][0]']
#  lization)
#
#  block_2_expand (Conv2D)        (None, 56, 56, 144)  3456        ['block_1_project_BN[0][0]']
#
#  block_2_expand_BN (BatchNormal  (None, 56, 56, 144)  576        ['block_2_expand[0][0]']
#  ization)
#
#  block_2_expand_relu (ReLU)     (None, 56, 56, 144)  0           ['block_2_expand_BN[0][0]']
#
#  block_2_depthwise (DepthwiseCo  (None, 56, 56, 144)  1296       ['block_2_expand_relu[0][0]']
#  nv2D)
#
#  block_2_depthwise_BN (BatchNor  (None, 56, 56, 144)  576        ['block_2_depthwise[0][0]']
#  malization)
#
#  block_2_depthwise_relu (ReLU)  (None, 56, 56, 144)  0           ['block_2_depthwise_BN[0][0]']
#
#  block_2_project (Conv2D)       (None, 56, 56, 24)   3456        ['block_2_depthwise_relu[0][0]']
#
#  block_2_project_BN (BatchNorma  (None, 56, 56, 24)  96          ['block_2_project[0][0]']
#  lization)
#
#  block_2_add (Add)              (None, 56, 56, 24)   0           ['block_1_project_BN[0][0]',
#                                                                   'block_2_project_BN[0][0]']
#
#  block_3_expand (Conv2D)        (None, 56, 56, 144)  3456        ['block_2_add[0][0]']
#
#  block_3_expand_BN (BatchNormal  (None, 56, 56, 144)  576        ['block_3_expand[0][0]']
#  ization)
#
#  block_3_expand_relu (ReLU)     (None, 56, 56, 144)  0           ['block_3_expand_BN[0][0]']
#
#  block_3_pad (ZeroPadding2D)    (None, 57, 57, 144)  0           ['block_3_expand_relu[0][0]']
#
#  block_3_depthwise (DepthwiseCo  (None, 28, 28, 144)  1296       ['block_3_pad[0][0]']
#  nv2D)
#
#  block_3_depthwise_BN (BatchNor  (None, 28, 28, 144)  576        ['block_3_depthwise[0][0]']
#  malization)
#
#  block_3_depthwise_relu (ReLU)  (None, 28, 28, 144)  0           ['block_3_depthwise_BN[0][0]']
#
#  block_3_project (Conv2D)       (None, 28, 28, 32)   4608        ['block_3_depthwise_relu[0][0]']
#
#  block_3_project_BN (BatchNorma  (None, 28, 28, 32)  128         ['block_3_project[0][0]']
#  lization)
#
#  block_4_expand (Conv2D)        (None, 28, 28, 192)  6144        ['block_3_project_BN[0][0]']
#
#  block_4_expand_BN (BatchNormal  (None, 28, 28, 192)  768        ['block_4_expand[0][0]']
#  ization)
#
#  block_4_expand_relu (ReLU)     (None, 28, 28, 192)  0           ['block_4_expand_BN[0][0]']
#
#  block_4_depthwise (DepthwiseCo  (None, 28, 28, 192)  1728       ['block_4_expand_relu[0][0]']
#  nv2D)
#
#  block_4_depthwise_BN (BatchNor  (None, 28, 28, 192)  768        ['block_4_depthwise[0][0]']
#  malization)
#
#  block_4_depthwise_relu (ReLU)  (None, 28, 28, 192)  0           ['block_4_depthwise_BN[0][0]']
#
#  block_4_project (Conv2D)       (None, 28, 28, 32)   6144        ['block_4_depthwise_relu[0][0]']
#
#  block_4_project_BN (BatchNorma  (None, 28, 28, 32)  128         ['block_4_project[0][0]']
#  lization)
#
#  block_4_add (Add)              (None, 28, 28, 32)   0           ['block_3_project_BN[0][0]',
#                                                                   'block_4_project_BN[0][0]']
#
#  block_5_expand (Conv2D)        (None, 28, 28, 192)  6144        ['block_4_add[0][0]']
#
#  block_5_expand_BN (BatchNormal  (None, 28, 28, 192)  768        ['block_5_expand[0][0]']
#  ization)
#
#  block_5_expand_relu (ReLU)     (None, 28, 28, 192)  0           ['block_5_expand_BN[0][0]']
#
#  block_5_depthwise (DepthwiseCo  (None, 28, 28, 192)  1728       ['block_5_expand_relu[0][0]']
#  nv2D)
#
#  block_5_depthwise_BN (BatchNor  (None, 28, 28, 192)  768        ['block_5_depthwise[0][0]']
#  malization)
#
#  block_5_depthwise_relu (ReLU)  (None, 28, 28, 192)  0           ['block_5_depthwise_BN[0][0]']
#
#  block_5_project (Conv2D)       (None, 28, 28, 32)   6144        ['block_5_depthwise_relu[0][0]']
#
#  block_5_project_BN (BatchNorma  (None, 28, 28, 32)  128         ['block_5_project[0][0]']
#  lization)
#
#  block_5_add (Add)              (None, 28, 28, 32)   0           ['block_4_add[0][0]',
#                                                                   'block_5_project_BN[0][0]']
#
#  block_6_expand (Conv2D)        (None, 28, 28, 192)  6144        ['block_5_add[0][0]']
#
#  block_6_expand_BN (BatchNormal  (None, 28, 28, 192)  768        ['block_6_expand[0][0]']
#  ization)
#
#  block_6_expand_relu (ReLU)     (None, 28, 28, 192)  0           ['block_6_expand_BN[0][0]']
#
#  block_6_pad (ZeroPadding2D)    (None, 29, 29, 192)  0           ['block_6_expand_relu[0][0]']
#
#  block_6_depthwise (DepthwiseCo  (None, 14, 14, 192)  1728       ['block_6_pad[0][0]']
#  nv2D)
#
#  block_6_depthwise_BN (BatchNor  (None, 14, 14, 192)  768        ['block_6_depthwise[0][0]']
#  malization)
#
#  block_6_depthwise_relu (ReLU)  (None, 14, 14, 192)  0           ['block_6_depthwise_BN[0][0]']
#
#  block_6_project (Conv2D)       (None, 14, 14, 64)   12288       ['block_6_depthwise_relu[0][0]']
#
#  block_6_project_BN (BatchNorma  (None, 14, 14, 64)  256         ['block_6_project[0][0]']
#  lization)
#
#  block_7_expand (Conv2D)        (None, 14, 14, 384)  24576       ['block_6_project_BN[0][0]']
#
#  block_7_expand_BN (BatchNormal  (None, 14, 14, 384)  1536       ['block_7_expand[0][0]']
#  ization)
#
#  block_7_expand_relu (ReLU)     (None, 14, 14, 384)  0           ['block_7_expand_BN[0][0]']
#
#  block_7_depthwise (DepthwiseCo  (None, 14, 14, 384)  3456       ['block_7_expand_relu[0][0]']
#  nv2D)
#
#  block_7_depthwise_BN (BatchNor  (None, 14, 14, 384)  1536       ['block_7_depthwise[0][0]']
#  malization)
#
#  block_7_depthwise_relu (ReLU)  (None, 14, 14, 384)  0           ['block_7_depthwise_BN[0][0]']
#
#  block_7_project (Conv2D)       (None, 14, 14, 64)   24576       ['block_7_depthwise_relu[0][0]']
#
#  block_7_project_BN (BatchNorma  (None, 14, 14, 64)  256         ['block_7_project[0][0]']
#  lization)
#
#  block_7_add (Add)              (None, 14, 14, 64)   0           ['block_6_project_BN[0][0]',
#                                                                   'block_7_project_BN[0][0]']
#
#  block_8_expand (Conv2D)        (None, 14, 14, 384)  24576       ['block_7_add[0][0]']
#
#  block_8_expand_BN (BatchNormal  (None, 14, 14, 384)  1536       ['block_8_expand[0][0]']
#  ization)
#
#  block_8_expand_relu (ReLU)     (None, 14, 14, 384)  0           ['block_8_expand_BN[0][0]']
#
#  block_8_depthwise (DepthwiseCo  (None, 14, 14, 384)  3456       ['block_8_expand_relu[0][0]']
#  nv2D)
#
#  block_8_depthwise_BN (BatchNor  (None, 14, 14, 384)  1536       ['block_8_depthwise[0][0]']
#  malization)
#
#  block_8_depthwise_relu (ReLU)  (None, 14, 14, 384)  0           ['block_8_depthwise_BN[0][0]']
#
#  block_8_project (Conv2D)       (None, 14, 14, 64)   24576       ['block_8_depthwise_relu[0][0]']
#
#  block_8_project_BN (BatchNorma  (None, 14, 14, 64)  256         ['block_8_project[0][0]']
#  lization)
#
#  block_8_add (Add)              (None, 14, 14, 64)   0           ['block_7_add[0][0]',
#                                                                   'block_8_project_BN[0][0]']
#
#  block_9_expand (Conv2D)        (None, 14, 14, 384)  24576       ['block_8_add[0][0]']
#
#  block_9_expand_BN (BatchNormal  (None, 14, 14, 384)  1536       ['block_9_expand[0][0]']
#  ization)
#
#  block_9_expand_relu (ReLU)     (None, 14, 14, 384)  0           ['block_9_expand_BN[0][0]']
#
#  block_9_depthwise (DepthwiseCo  (None, 14, 14, 384)  3456       ['block_9_expand_relu[0][0]']
#  nv2D)
#
#  block_9_depthwise_BN (BatchNor  (None, 14, 14, 384)  1536       ['block_9_depthwise[0][0]']
#  malization)
#
#  block_9_depthwise_relu (ReLU)  (None, 14, 14, 384)  0           ['block_9_depthwise_BN[0][0]']
#
#  block_9_project (Conv2D)       (None, 14, 14, 64)   24576       ['block_9_depthwise_relu[0][0]']
#
#  block_9_project_BN (BatchNorma  (None, 14, 14, 64)  256         ['block_9_project[0][0]']
#  lization)
#
#  block_9_add (Add)              (None, 14, 14, 64)   0           ['block_8_add[0][0]',
#                                                                   'block_9_project_BN[0][0]']
#
#  block_10_expand (Conv2D)       (None, 14, 14, 384)  24576       ['block_9_add[0][0]']
#
#  block_10_expand_BN (BatchNorma  (None, 14, 14, 384)  1536       ['block_10_expand[0][0]']
#  lization)
#
#  block_10_expand_relu (ReLU)    (None, 14, 14, 384)  0           ['block_10_expand_BN[0][0]']
#
#  block_10_depthwise (DepthwiseC  (None, 14, 14, 384)  3456       ['block_10_expand_relu[0][0]']
#  onv2D)
#
#  block_10_depthwise_BN (BatchNo  (None, 14, 14, 384)  1536       ['block_10_depthwise[0][0]']
#  rmalization)
#
#  block_10_depthwise_relu (ReLU)  (None, 14, 14, 384)  0          ['block_10_depthwise_BN[0][0]']
#
#  block_10_project (Conv2D)      (None, 14, 14, 96)   36864       ['block_10_depthwise_relu[0][0]']
#
#  block_10_project_BN (BatchNorm  (None, 14, 14, 96)  384         ['block_10_project[0][0]']
#  alization)
#
#  block_11_expand (Conv2D)       (None, 14, 14, 576)  55296       ['block_10_project_BN[0][0]']
#
#  block_11_expand_BN (BatchNorma  (None, 14, 14, 576)  2304       ['block_11_expand[0][0]']
#  lization)
#
#  block_11_expand_relu (ReLU)    (None, 14, 14, 576)  0           ['block_11_expand_BN[0][0]']
#
#  block_11_depthwise (DepthwiseC  (None, 14, 14, 576)  5184       ['block_11_expand_relu[0][0]']
#  onv2D)
#
#  block_11_depthwise_BN (BatchNo  (None, 14, 14, 576)  2304       ['block_11_depthwise[0][0]']
#  rmalization)
#
#  block_11_depthwise_relu (ReLU)  (None, 14, 14, 576)  0          ['block_11_depthwise_BN[0][0]']
#
#  block_11_project (Conv2D)      (None, 14, 14, 96)   55296       ['block_11_depthwise_relu[0][0]']
#
#  block_11_project_BN (BatchNorm  (None, 14, 14, 96)  384         ['block_11_project[0][0]']
#  alization)
#
#  block_11_add (Add)             (None, 14, 14, 96)   0           ['block_10_project_BN[0][0]',
#                                                                   'block_11_project_BN[0][0]']
#
#  block_12_expand (Conv2D)       (None, 14, 14, 576)  55296       ['block_11_add[0][0]']
#
#  block_12_expand_BN (BatchNorma  (None, 14, 14, 576)  2304       ['block_12_expand[0][0]']
#  lization)
#
#  block_12_expand_relu (ReLU)    (None, 14, 14, 576)  0           ['block_12_expand_BN[0][0]']
#
#  block_12_depthwise (DepthwiseC  (None, 14, 14, 576)  5184       ['block_12_expand_relu[0][0]']
#  onv2D)
#
#  block_12_depthwise_BN (BatchNo  (None, 14, 14, 576)  2304       ['block_12_depthwise[0][0]']
#  rmalization)
#
#  block_12_depthwise_relu (ReLU)  (None, 14, 14, 576)  0          ['block_12_depthwise_BN[0][0]']
#
#  block_12_project (Conv2D)      (None, 14, 14, 96)   55296       ['block_12_depthwise_relu[0][0]']
#
#  block_12_project_BN (BatchNorm  (None, 14, 14, 96)  384         ['block_12_project[0][0]']
#  alization)
#
#  block_12_add (Add)             (None, 14, 14, 96)   0           ['block_11_add[0][0]',
#                                                                   'block_12_project_BN[0][0]']
#
#  block_13_expand (Conv2D)       (None, 14, 14, 576)  55296       ['block_12_add[0][0]']
#
#  block_13_expand_BN (BatchNorma  (None, 14, 14, 576)  2304       ['block_13_expand[0][0]']
#  lization)
#
#  block_13_expand_relu (ReLU)    (None, 14, 14, 576)  0           ['block_13_expand_BN[0][0]']
#
#  block_13_pad (ZeroPadding2D)   (None, 15, 15, 576)  0           ['block_13_expand_relu[0][0]']
#
#  block_13_depthwise (DepthwiseC  (None, 7, 7, 576)   5184        ['block_13_pad[0][0]']
#  onv2D)
#
#  block_13_depthwise_BN (BatchNo  (None, 7, 7, 576)   2304        ['block_13_depthwise[0][0]']
#  rmalization)
#
#  block_13_depthwise_relu (ReLU)  (None, 7, 7, 576)   0           ['block_13_depthwise_BN[0][0]']
#
#  block_13_project (Conv2D)      (None, 7, 7, 160)    92160       ['block_13_depthwise_relu[0][0]']
#
#  block_13_project_BN (BatchNorm  (None, 7, 7, 160)   640         ['block_13_project[0][0]']
#  alization)
#
#  block_14_expand (Conv2D)       (None, 7, 7, 960)    153600      ['block_13_project_BN[0][0]']
#
#  block_14_expand_BN (BatchNorma  (None, 7, 7, 960)   3840        ['block_14_expand[0][0]']
#  lization)
#
#  block_14_expand_relu (ReLU)    (None, 7, 7, 960)    0           ['block_14_expand_BN[0][0]']
#
#  block_14_depthwise (DepthwiseC  (None, 7, 7, 960)   8640        ['block_14_expand_relu[0][0]']
#  onv2D)
#
#  block_14_depthwise_BN (BatchNo  (None, 7, 7, 960)   3840        ['block_14_depthwise[0][0]']
#  rmalization)
#
#  block_14_depthwise_relu (ReLU)  (None, 7, 7, 960)   0           ['block_14_depthwise_BN[0][0]']
#
#  block_14_project (Conv2D)      (None, 7, 7, 160)    153600      ['block_14_depthwise_relu[0][0]']
#
#  block_14_project_BN (BatchNorm  (None, 7, 7, 160)   640         ['block_14_project[0][0]']
#  alization)
#
#  block_14_add (Add)             (None, 7, 7, 160)    0           ['block_13_project_BN[0][0]',
#                                                                   'block_14_project_BN[0][0]']
#
#  block_15_expand (Conv2D)       (None, 7, 7, 960)    153600      ['block_14_add[0][0]']
#
#  block_15_expand_BN (BatchNorma  (None, 7, 7, 960)   3840        ['block_15_expand[0][0]']
#  lization)
#
#  block_15_expand_relu (ReLU)    (None, 7, 7, 960)    0           ['block_15_expand_BN[0][0]']
#
#  block_15_depthwise (DepthwiseC  (None, 7, 7, 960)   8640        ['block_15_expand_relu[0][0]']
#  onv2D)
#
#  block_15_depthwise_BN (BatchNo  (None, 7, 7, 960)   3840        ['block_15_depthwise[0][0]']
#  rmalization)
#
#  block_15_depthwise_relu (ReLU)  (None, 7, 7, 960)   0           ['block_15_depthwise_BN[0][0]']
#
#  block_15_project (Conv2D)      (None, 7, 7, 160)    153600      ['block_15_depthwise_relu[0][0]']
#
#  block_15_project_BN (BatchNorm  (None, 7, 7, 160)   640         ['block_15_project[0][0]']
#  alization)
#
#  block_15_add (Add)             (None, 7, 7, 160)    0           ['block_14_add[0][0]',
#                                                                   'block_15_project_BN[0][0]']
#
#  block_16_expand (Conv2D)       (None, 7, 7, 960)    153600      ['block_15_add[0][0]']
#
#  block_16_expand_BN (BatchNorma  (None, 7, 7, 960)   3840        ['block_16_expand[0][0]']
#  lization)
#
#  block_16_expand_relu (ReLU)    (None, 7, 7, 960)    0           ['block_16_expand_BN[0][0]']
#
#  block_16_depthwise (DepthwiseC  (None, 7, 7, 960)   8640        ['block_16_expand_relu[0][0]']
#  onv2D)
#
#  block_16_depthwise_BN (BatchNo  (None, 7, 7, 960)   3840        ['block_16_depthwise[0][0]']
#  rmalization)
#
#  block_16_depthwise_relu (ReLU)  (None, 7, 7, 960)   0           ['block_16_depthwise_BN[0][0]']
#
#  block_16_project (Conv2D)      (None, 7, 7, 320)    307200      ['block_16_depthwise_relu[0][0]']
#
#  block_16_project_BN (BatchNorm  (None, 7, 7, 320)   1280        ['block_16_project[0][0]']
#  alization)
#
#  Conv_1 (Conv2D)                (None, 7, 7, 1280)   409600      ['block_16_project_BN[0][0]']
#
#  Conv_1_bn (BatchNormalization)  (None, 7, 7, 1280)  5120        ['Conv_1[0][0]']
#
#  out_relu (ReLU)                (None, 7, 7, 1280)   0           ['Conv_1_bn[0][0]']
#
#  global_average_pooling2d_8 (Gl  (None, 1280)        0           ['out_relu[0][0]']
#  obalAveragePooling2D)
#
#  dropout_2 (Dropout)            (None, 1280)         0           ['global_average_pooling2d_8[0][0
#                                                                  ]']
#
#  dense_8 (Dense)                (None, 1)            1281        ['dropout_2[0][0]']
#
# ==================================================================================================
# Total params: 2,259,265
# Trainable params: 1,281
# Non-trainable params: 2,257,984
# __________________________________________________________________________________________________

# %% [markdown]
# # Model Training

# %% [markdown]
# Had an issue where the image name had .jpg 3 times on it so this code removes the additional .jpg

# %%
#print(df.head)
df['image_name'] = df['image_name'].apply(lambda x: x.replace('.jpg', ''))

#  add .jpg back to image name
df['image_name'] = df['image_name'].apply(lambda x: f"{x}.jpg")

print(df['image_name'].head())
# Out:
# 2     ISIC_0052212.jpg
# 12    ISIC_0076995.jpg
# 26    ISIC_0084086.jpg
# 27    ISIC_0084270.jpg
# 28    ISIC_0084395.jpg
# Name: image_name, dtype: object

# %%
import tensorflow as tf
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split

# Split the dataframe into training and validation sets
df_train, df_valid = train_test_split(df, test_size=0.2, random_state=42)

image_directory = '/content/drive/MyDrive/ISIC_2020_Training_JPEG/train/resized'

# Create an ImageDataGenerator object
train_datagen = ImageDataGenerator(rescale=1./255)
valid_datagen = ImageDataGenerator(rescale=1./255)

# Convert the labels back to string
df['benign_malignant'] = df['benign_malignant'].replace({0: 'benign', 1: 'malignant'})

# Create data flows
train_generator = train_datagen.flow_from_dataframe(
    dataframe=df_train,
    directory= image_directory,
    x_col="image_name",
    y_col="benign_malignant",
    target_size=(224, 224),
    batch_size=32,
    class_mode='binary'
)

valid_generator = valid_datagen.flow_from_dataframe(
    dataframe=df_valid,
    directory= image_directory,
    x_col="image_name",
    y_col="benign_malignant",
    target_size=(224, 224),
    batch_size=32,
    class_mode='binary'
)

# Create a MobileNetV2 model
base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Add a new top layer
x = base_model.output
x = tf.keras.layers.GlobalAveragePooling2D()(x)
predictions = tf.keras.layers.Dense(1, activation='sigmoid')(x)

# This is the model we will train
model = tf.keras.models.Model(inputs=base_model.input, outputs=predictions)

# First: train only the top layers (which were randomly initialized)
for layer in base_model.layers:
    layer.trainable = False

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(
    train_generator,
    epochs=10,
    validation_data=valid_generator,
)
# Out:
# Found 4801 validated image filenames belonging to 2 classes.
# Found 1201 validated image filenames belonging to 2 classes.
# Epoch 1/10
# 151/151 [==============================] - 318s 2s/step - loss: 0.3111 - accuracy: 0.8904 - val_loss: 0.2892 - val_accuracy: 0.8968
# Epoch 2/10
# 151/151 [==============================] - 300s 2s/step - loss: 0.2459 - accuracy: 0.9088 - val_loss: 0.2823 - val_accuracy: 0.8909
# Epoch 3/10
# 151/151 [==============================] - 309s 2s/step - loss: 0.2334 - accuracy: 0.9102 - val_loss: 0.2806 - val_accuracy: 0.8976
# Epoch 4/10
# 151/151 [==============================] - 305s 2s/step - loss: 0.2236 - accuracy: 0.9148 - val_loss: 0.2781 - val_accuracy: 0.8976
# Epoch 5/10
# 151/151 [==============================] - 307s 2s/step - loss: 0.2170 - accuracy: 0.9150 - val_loss: 0.2798 - val_accuracy: 0.9017
# Epoch 6/10
# 151/151 [==============================] - 307s 2s/step - loss: 0.2106 - accuracy: 0.9167 - val_loss: 0.2798 - val_accuracy: 0.8934
# Epoch 7/10
# 151/151 [==============================] - 306s 2s/step - loss: 0.2044 - accuracy: 0.9204 - val_loss: 0.2768 - val_accuracy: 0.8959
# Epoch 8/10
# 151/151 [==============================] - 306s 2s/step - loss: 0.2008 - accuracy: 0.9223 - val_loss: 0.2779 - val_accuracy: 0.8876
# Epoch 9/10
# 151/151 [==============================] - 302s 2s/step - loss: 0.1977 - accuracy: 0.9250 - val_loss: 0.2780 - val_accuracy: 0.8934
# Epoch 10/10
# 151/151 [==============================] - 307s 2s/step - loss: 0.1915 - accuracy: 0.9261 - val_loss: 0.2787 - val_accuracy: 0.8926

# %% [markdown]
# Save Model
# ---

# %%
model.save("/content/drive/MyDrive/DataModel")
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 53). These functions will not be directly callable after loading.

# %% [markdown]
# # Model Evaluation

# %%
# Create a test generator
test_generator = train_datagen.flow_from_dataframe(
    dataframe= df_train,
    directory=image_directory,
    x_col="image_name",
    y_col="benign_malignant",
    target_size=(224, 224),
    batch_size=32,
    class_mode='binary',
    shuffle=False
)

# Evaluate the model
loss, accuracy = model.evaluate(test_generator)

# Print the test loss and accuracy
print(f"Test loss: {loss}")
print(f"Test accuracy: {accuracy}")
# Out:
# Found 4801 validated image filenames belonging to 2 classes.
# 151/151 [==============================] - 220s 1s/step - loss: 0.1891 - accuracy: 0.9371
# Test loss: 0.18913358449935913
# Test accuracy: 0.9370964169502258

# %% [markdown]
# #Model Testing

# %% [markdown]
# Model Testing with images found in google

# %%
import cv2
import numpy as np
from keras.models import load_model

# Load the pre-trained model
model = load_model('/content/drive/MyDrive/DataModel')

# Set the image path
image_path = '/content/drive/MyDrive/Google_Melanoma/benign.png'

# change the file at end of image_path to any of these:
# benign.png result should be benign
# melanoma_1.png result should be malignant
# Melanoma.jpg result should be malignant


# Load and preprocess the image
image = cv2.imread(image_path)

# Check if the image was loaded successfully
if image is None:
    print(f"Failed to load image: {image_path}")
else:
    image = cv2.resize(image, (224, 224))
    image = image / 255.0  # Normalize pixel values
    image = np.expand_dims(image, axis=0)  # Reshape to match the input shape of the model

    # Make a prediction
    prediction = model.predict(image)

    # Interpret the result
    if prediction[0][0] < 0.5:
        print("Predicted class: Benign")
    else:
        print("Predicted class: Malignant")
    print(f"Probability: {prediction[0][0]:.2f}") # displays probability, close to 0 meaning benign, clost to 1 meaning malignant and if its 0.5 then the model is unsure
# Out:
# 1/1 [==============================] - 1s 952ms/step
# Predicted class: Benign
# Probability: 0.04

# %% [markdown]
# Model Testing with ISIC test data

# %%
import cv2
import numpy as np
from keras.models import load_model
import os

# Load the pre-trained model
model = load_model('/content/drive/MyDrive/DataModel')

# Set the directory path
directory_path = test_image_path

# Loop over all files in the directory
for filename in os.listdir(directory_path):
    # Only process .png files
    if filename.endswith(".jpg"):
        # Construct full image path
        image_path = os.path.join(directory_path, filename)

        # Load and preprocess the image
        image = cv2.imread(image_path)

        # Check if the image was loaded successfully
        if image is None:
            print(f"Failed to load image: {image_path}")
        else:
            image = cv2.resize(image, (224, 224))
            image = image / 255.0  # Normalize pixel values
            image = np.expand_dims(image, axis=0)  # Reshape to match the input shape of the model

            # Make a prediction
            prediction = model.predict(image)

            # Interpret the result
            if prediction[0][0] < 0.5:
                print(f"{filename}: Predicted class: Benign")
            else:
                print(f"{filename}: Predicted class: Malignant")
            print(f"Probability: {prediction[0][0]:.2f}")
# Out:
# Streaming output truncated to the last 5000 lines.
# ISIC_7750466.jpg: Predicted class: Benign
# Probability: 0.07
# 1/1 [==============================] - 0s 62ms/step
# ISIC_0223354.jpg: Predicted class: Benign
# Probability: 0.20
# 1/1 [==============================] - 0s 71ms/step
# ISIC_2531776.jpg: Predicted class: Benign
# Probability: 0.34
# 1/1 [==============================] - 0s 58ms/step
# ISIC_2323273.jpg: Predicted class: Benign
# Probability: 0.17
# 1/1 [==============================] - 0s 58ms/step
# ISIC_0416431.jpg: Predicted class: Benign
# Probability: 0.16
# 1/1 [==============================] - 0s 57ms/step
# ISIC_1789614.jpg: Predicted class: Benign
# Probability: 0.05
# 1/1 [==============================] - 0s 92ms/step
# ISIC_0223760.jpg: Predicted class: Malignant
# Probability: 0.60
# 1/1 [==============================] - 0s 60ms/step
# ISIC_7259357.jpg: Predicted class: Benign
# Probability: 0.09
# 1/1 [==============================] - 0s 62ms/step
# ISIC_3084021.jpg: Predicted class: Benign
# Probability: 0.25
# 1/1 [==============================] - 0s 57ms/step
# ISIC_2731928.jpg: Predicted class: Benign
# Probability: 0.30
# 1/1 [==============================] - 0s 58ms/step
# ISIC_9843071.jpg: Predicted class: Benign
# Probability: 0.07
# 1/1 [==============================] - 0s 62ms/step
# ISIC_6182913.jpg: Predicted class: Benign
# Probability: 0.08
# 1/1 [==============================] - 0s 59ms/step
# ISIC_3075041.jpg: Predicted class: Benign
# Probability: 0.07
# 1/1 [==============================] - 0s 59ms/step
# ISIC_2343290.jpg: Predicted class: Benign
# Probability: 0.15
# 1/1 [==============================] - 0s 72ms/step
# ISIC_1727295.jpg: Predicted class: Benign
# Probability: 0.32
# 1/1 [==============================] - 0s 92ms/step
# ISIC_9539153.jpg: Predicted class: Benign
# Probability: 0.25
# 1/1 [==============================] - 0s 95ms/step
# ISIC_1539449.jpg: Predicted class: Benign
# Probability: 0.06
# 1/1 [==============================] - 0s 62ms/step
# ISIC_5044571.jpg: Predicted class: Benign
# Probability: 0.35
# 1/1 [==============================] - 0s 56ms/step
# ISIC_0319131.jpg: Predicted class: Benign
# Probability: 0.28
# 1/1 [==============================] - 0s 59ms/step
# ISIC_8921417.jpg: Predicted class: Malignant
# Probability: 0.91
# 1/1 [==============================] - 0s 56ms/step
# ISIC_6719897.jpg: Predicted class: Benign
# Probability: 0.41
# 1/1 [==============================] - 0s 58ms/step
# ISIC_3666967.jpg: Predicted class: Benign
# Probability: 0.24
# 1/1 [==============================] - 0s 56ms/step
# ISIC_5872609.jpg: Predicted class: Malignant
# Probability: 0.67
# 1/1 [==============================] - 0s 57ms/step
# ISIC_1657960.jpg: Predicted class: Benign
# Probability: 0.03
# 1/1 [==============================] - 0s 60ms/step
# ISIC_5631587.jpg: Predicted class: Benign
# Probability: 0.26
# 1/1 [==============================] - 0s 92ms/step
# ISIC_9497933.jpg: Predicted class: Benign
# Probability: 0.26
# 1/1 [==============================] - 0s 101ms/step
# ISIC_0813352.jpg: Predicted class: Benign
# Probability: 0.24
# 1/1 [==============================] - 0s 95ms/step
# ISIC_3639434.jpg: Predicted class: Benign
# Probability: 0.06
# 1/1 [==============================] - 0s 61ms/step
# ISIC_9681414.jpg: Predicted class: Benign
# Probability: 0.06
# 1/1 [==============================] - 0s 57ms/step
# ISIC_2913511.jpg: Predicted class: Benign
# Probability: 0.15
# 1/1 [==============================] - 0s 59ms/step
# ISIC_9095798.jpg: Predicted class: Malignant
# Probability: 0.68
# 1/1 [==============================] - 0s 58ms/step
# ISIC_8263315.jpg: Predicted class: Benign
# Probability: 0.08
# 1/1 [==============================] - 0s 61ms/step
# ISIC_9764424.jpg: Predicted class: Benign
# Probability: 0.41
# 1/1 [==============================] - 0s 61ms/step
# ISIC_8161707.jpg: Predicted class: Benign
# Probability: 0.11
# 1/1 [==============================] - 0s 58ms/step
# ISIC_5884699.jpg: Predicted class: Malignant
# Probability: 0.65
# 1/1 [==============================] - 0s 70ms/step
# ISIC_8928109.jpg: Predicted class: Benign
# Probability: 0.22
# 1/1 [==============================] - 0s 59ms/step
# ISIC_8229220.jpg: Predicted class: Benign
# Probability: 0.22
# 1/1 [==============================] - 0s 91ms/step
# ISIC_9318490.jpg: Predicted class: Malignant
# Probability: 0.76
# 1/1 [==============================] - 0s 91ms/step
# ISIC_5403880.jpg: Predicted class: Malignant
# Probability: 0.54
# 1/1 [==============================] - 0s 56ms/step
# ISIC_8295052.jpg: Predicted class: Benign
# Probability: 0.19
# 1/1 [==============================] - 0s 58ms/step
# ISIC_4455115.jpg: Predicted class: Benign
# Probability: 0.02
# 1/1 [==============================] - 0s 55ms/step
# ISIC_8341620.jpg: Predicted class: Benign
# Probability: 0.47
# 1/1 [==============================] - 0s 58ms/step
# ISIC_8961647.jpg: Predicted class: Malignant
# Probability: 0.80
# 1/1 [==============================] - 0s 57ms/step
# ISIC_3759225.jpg: Predicted class: Benign
# Probability: 0.48
# 1/1 [==============================] - 0s 67ms/step
# ISIC_0644758.jpg: Predicted class: Benign
# Probability: 0.08
# 1/1 [==============================] - 0s 57ms/step
# ISIC_0226234.jpg: Predicted class: Benign
# Probability: 0.03
# 1/1 [==============================] - 0s 58ms/step
# ISIC_8389896.jpg: Predicted class: Malignant
# Probability: 0.77
# 1/1 [==============================] - 0s 55ms/step
# ISIC_2024876.jpg: Predicted class: Benign
# Probability: 0.25
# 1/1 [==============================] - 0s 87ms/step
# ISIC_4006453.jpg: Predicted class: Benign
# Probability: 0.14
# 1/1 [==============================] - 0s 91ms/step
# ISIC_5386993.jpg: Predicted class: Benign
# Probability: 0.36
# 1/1 [==============================] - 0s 63ms/step
# ISIC_6129280.jpg: Predicted class: Benign
# Probability: 0.24
# 1/1 [==============================] - 0s 58ms/step
# ISIC_5154538.jpg: Predicted class: Benign
# Probability: 0.03
# 1/1 [==============================] - 0s 59ms/step
# ISIC_8094551.jpg: Predicted class: Malignant
# Probability: 0.82
# 1/1 [==============================] - 0s 58ms/step
# ISIC_6455252.jpg: Predicted class: Benign
# Probability: 0.13
# 1/1 [==============================] - 0s 58ms/step
# ISIC_1675841.jpg: Predicted class: Benign
# Probability: 0.02
# 1/1 [==============================] - 0s 58ms/step
# ISIC_8761931.jpg: Predicted class: Malignant
# Probability: 0.54
# 1/1 [==============================] - 0s 58ms/step
# ISIC_9786628.jpg: Predicted class: Malignant
# Probability: 0.72
# 1/1 [==============================] - 0s 99ms/step
# ISIC_8487046.jpg: Predicted class: Benign
# Probability: 0.15
# 1/1 [==============================] - 0s 92ms/step
# ISIC_1596422.jpg: Predicted class: Benign
# Probability: 0.25
# 1/1 [==============================] - 0s 98ms/step
# ISIC_4795502.jpg: Predicted class: Benign
# Probability: 0.26
# 1/1 [==============================] - 0s 63ms/step
# ISIC_4442884.jpg: Predicted class: Benign
# Probability: 0.02
# 1/1 [==============================] - 0s 62ms/step
# ISIC_2610835.jpg: Predicted class: Benign
# Probability: 0.07
# 1/1 [==============================] - 0s 57ms/step
# ISIC_6452363.jpg: Predicted class: Benign
# Probability: 0.15
# 1/1 [==============================] - 0s 61ms/step
# ISIC_9065092.jpg: Predicted class: Benign
# Probability: 0.21
# 1/1 [==============================] - 0s 63ms/step
# ISIC_7252876.jpg: Predicted class: Benign
# Probability: 0.15
# 1/1 [==============================] - 0s 62ms/step
# ISIC_4090757.jpg: Predicted class: Benign
# Probability: 0.15
# 1/1 [==============================] - 0s 67ms/step
# ISIC_5819533.jpg: Predicted class: Malignant
# Probability: 0.59
# 1/1 [==============================] - 0s 59ms/step
# ISIC_1527539.jpg: Predicted class: Benign
# Probability: 0.16
# 1/1 [==============================] - 0s 65ms/step
# ISIC_0297539.jpg: Predicted class: Benign
# Probability: 0.46
# 1/1 [==============================] - 0s 66ms/step
# ISIC_6364521.jpg: Predicted class: Benign
# Probability: 0.39
# 1/1 [==============================] - 0s 90ms/step
# ISIC_2099194.jpg: Predicted class: Benign
# Probability: 0.28
# 1/1 [==============================] - 0s 91ms/step
# ISIC_2466179.jpg: Predicted class: Benign
# Probability: 0.03
# 1/1 [==============================] - 0s 57ms/step
# ISIC_4587813.jpg: Predicted class: Benign
# Probability: 0.04
# 1/1 [==============================] - 0s 61ms/step
# ISIC_9184615.jpg: Predicted class: Malignant
# Probability: 0.62
# 1/1 [==============================] - 0s 58ms/step
# ISIC_6820094.jpg: Predicted class: Benign
# Probability: 0.02
# 1/1 [==============================] - 0s 59ms/step
# ISIC_2294605.jpg: Predicted class: Benign
# Probability: 0.19
# 1/1 [==============================] - 0s 60ms/step
# ISIC_5817573.jpg: Predicted class: Benign
# Probability: 0.33
# 1/1 [==============================] - 0s 60ms/step
# ISIC_3572957.jpg: Predicted class: Benign
# Probability: 0.29
# 1/1 [==============================] - 0s 61ms/step
# ISIC_8641927.jpg: Predicted class: Benign
# Probability: 0.10
# 1/1 [==============================] - 0s 92ms/step
# ISIC_3187460.jpg: Predicted class: Benign
# Probability: 0.24
# 1/1 [==============================] - 0s 138ms/step
# ISIC_4135551.jpg: Predicted class: Benign
# Probability: 0.41
# 1/1 [==============================] - 0s 130ms/step
# ISIC_3077337.jpg: Predicted class: Benign
# Probability: 0.16
# 1/1 [==============================] - 0s 106ms/step
# ISIC_9273015.jpg: Predicted class: Benign
# Probability: 0.36
# 1/1 [==============================] - 0s 94ms/step
# ISIC_6692114.jpg: Predicted class: Benign
# Probability: 0.34
# 1/1 [==============================] - 0s 56ms/step
# ISIC_3920748.jpg: Predicted class: Benign
# Probability: 0.05
# 1/1 [==============================] - 0s 65ms/step
# ISIC_2426423.jpg: Predicted class: Benign
# Probability: 0.19
# 1/1 [==============================] - 0s 61ms/step
# ISIC_8818534.jpg: Predicted class: Benign
# Probability: 0.04
# 1/1 [==============================] - 0s 64ms/step
# ISIC_1252180.jpg: Predicted class: Benign
# Probability: 0.16
# 1/1 [==============================] - 0s 59ms/step
# ISIC_5800043.jpg: Predicted class: Benign
# Probability: 0.19
# 1/1 [==============================] - 0s 57ms/step
# ISIC_2025954.jpg: Predicted class: Benign
# Probability: 0.26
# 1/1 [==============================] - 0s 88ms/step
# ISIC_8410986.jpg: Predicted class: Benign
# Probability: 0.49
# 1/1 [==============================] - 0s 93ms/step
# ISIC_6454666.jpg: Predicted class: Benign
# Probability: 0.12
# 1/1 [==============================] - 0s 57ms/step
# ISIC_9009245.jpg: Predicted class: Benign
# Probability: 0.48
# 1/1 [==============================] - 0s 57ms/step
# ISIC_2479848.jpg: Predicted class: Malignant
# Probability: 0.66
# 1/1 [==============================] - 0s 59ms/step
# ISIC_0714126.jpg: Predicted class: Malignant
# Probability: 0.56
# 1/1 [==============================] - 0s 60ms/step
# ISIC_1747010.jpg: Predicted class: Malignant
# Probability: 0.55
# 1/1 [==============================] - 0s 60ms/step
# ISIC_2845014.jpg: Predicted class: Malignant
# Probability: 0.63
# 1/1 [==============================] - 0s 56ms/step
# ISIC_6306932.jpg: Predicted class: Benign
# Probability: 0.29
# 1/1 [==============================] - 0s 61ms/step
# ISIC_7317291.jpg: Predicted class: Benign
# Probability: 0.26
# 1/1 [==============================] - 0s 60ms/step
# ISIC_7553223.jpg: Predicted class: Benign
# Probability: 0.20
# 1/1 [==============================] - 0s 56ms/step
# ISIC_6003295.jpg: Predicted class: Benign
# Probability: 0.06
# 1/1 [==============================] - 0s 89ms/step
# ISIC_8312411.jpg: Predicted class: Benign
# Probability: 0.42
# 1/1 [==============================] - 0s 91ms/step
# ISIC_1844023.jpg: Predicted class: Benign
# Probability: 0.22
# 1/1 [==============================] - 0s 94ms/step
# ISIC_3798140.jpg: Predicted class: Malignant
# Probability: 0.75
# 1/1 [==============================] - 0s 60ms/step
# ISIC_1739371.jpg: Predicted class: Benign
# Probability: 0.24
# 1/1 [==============================] - 0s 64ms/step
# ISIC_0928578.jpg: Predicted class: Benign
# Probability: 0.29
# 1/1 [==============================] - 0s 56ms/step
# ISIC_2003875.jpg: Predicted class: Malignant
# Probability: 0.52
# 1/1 [==============================] - 0s 56ms/step
# ISIC_4019558.jpg: Predicted class: Malignant
# Probability: 0.51
# 1/1 [==============================] - 0s 62ms/step
# ISIC_8918219.jpg: Predicted class: Malignant
# Probability: 0.78
# 1/1 [==============================] - 0s 58ms/step
# ISIC_0853184.jpg: Predicted class: Benign
# Probability: 0.03
# 1/1 [==============================] - 0s 64ms/step
# ISIC_3266762.jpg: Predicted class: Benign
# Probability: 0.20
# 1/1 [==============================] - 0s 89ms/step
# ISIC_8660499.jpg: Predicted class: Benign
# Probability: 0.05
# 1/1 [==============================] - 0s 93ms/step
# ISIC_6975773.jpg: Predicted class: Benign
# Probability: 0.33
# 1/1 [==============================] - 0s 60ms/step
# ISIC_0775579.jpg: Predicted class: Malignant
# Probability: 0.69
# 1/1 [==============================] - 0s 73ms/step
# ISIC_4899688.jpg: Predicted class: Benign
# Probability: 0.35
# 1/1 [==============================] - 0s 58ms/step
# ISIC_8208627.jpg: Predicted class: Benign
# Probability: 0.14
# 1/1 [==============================] - 0s 57ms/step
# ISIC_7667553.jpg: Predicted class: Benign
# Probability: 0.36
# 1/1 [==============================] - 0s 56ms/step
# ISIC_3601241.jpg: Predicted class: Benign
# Probability: 0.09
# 1/1 [==============================] - 0s 58ms/step
# ISIC_8362909.jpg: Predicted class: Benign
# Probability: 0.08
# 1/1 [==============================] - 0s 57ms/step
# ISIC_2574854.jpg: Predicted class: Benign
# Probability: 0.02
# 1/1 [==============================] - 0s 87ms/step
# ISIC_6590875.jpg: Predicted class: Benign
# Probability: 0.04
# 1/1 [==============================] - 0s 93ms/step
# ISIC_6350420.jpg: Predicted class: Benign
# Probability: 0.36
# 1/1 [==============================] - 0s 93ms/step
# ISIC_5466110.jpg: Predicted class: Benign
# Probability: 0.10
# 1/1 [==============================] - 0s 57ms/step
# ISIC_4848990.jpg: Predicted class: Malignant
# Probability: 0.85
# 1/1 [==============================] - 0s 58ms/step
# ISIC_1842457.jpg: Predicted class: Benign
# Probability: 0.20
# 1/1 [==============================] - 0s 56ms/step
# ISIC_6669353.jpg: Predicted class: Benign
# Probability: 0.16
# 1/1 [==============================] - 0s 57ms/step
# ISIC_1295270.jpg: Predicted class: Malignant
# Probability: 0.68
# 1/1 [==============================] - 0s 57ms/step
# ISIC_5745743.jpg: Predicted class: Benign
# Probability: 0.25
# 1/1 [==============================] - 0s 71ms/step
# ISIC_7433838.jpg: Predicted class: Malignant
# Probability: 0.77
# 1/1 [==============================] - 0s 56ms/step
# ISIC_8984115.jpg: Predicted class: Benign
# Probability: 0.05
# 1/1 [==============================] - 0s 58ms/step
# ISIC_0772578.jpg: Predicted class: Malignant
# Probability: 0.94
# 1/1 [==============================] - 0s 101ms/step
# ISIC_2501615.jpg: Predicted class: Benign
# Probability: 0.28
# 1/1 [==============================] - 0s 58ms/step
# ISIC_6913600.jpg: Predicted class: Benign
# Probability: 0.42
# 1/1 [==============================] - 0s 61ms/step
# ISIC_4979173.jpg: Predicted class: Benign
# Probability: 0.47
# 1/1 [==============================] - 0s 59ms/step
# ISIC_9289911.jpg: Predicted class: Benign
# Probability: 0.03
# 1/1 [==============================] - 0s 56ms/step
# ISIC_5287531.jpg: Predicted class: Benign
# Probability: 0.04
# 1/1 [==============================] - 0s 57ms/step
# ISIC_7857142.jpg: Predicted class: Benign
# Probability: 0.08
# 1/1 [==============================] - 0s 56ms/step
# ISIC_8886372.jpg: Predicted class: Benign
# Probability: 0.09
# 1/1 [==============================] - 0s 57ms/step
# ISIC_6504643.jpg: Predicted class: Benign
# Probability: 0.29
# 1/1 [==============================] - 0s 89ms/step
# ISIC_5135086.jpg: Predicted class: Benign
# Probability: 0.44
# 1/1 [==============================] - 0s 98ms/step
# ISIC_9430171.jpg: Predicted class: Benign
# Probability: 0.10
# 1/1 [==============================] - 0s 97ms/step
# ISIC_4399176.jpg: Predicted class: Benign
# Probability: 0.09
# 1/1 [==============================] - 0s 58ms/step
# ISIC_8918601.jpg: Predicted class: Malignant
# Probability: 0.50
# 1/1 [==============================] - 0s 62ms/step
# ISIC_5165301.jpg: Predicted class: Benign
# Probability: 0.15
# 1/1 [==============================] - 0s 57ms/step
# ISIC_4553607.jpg: Predicted class: Benign
# Probability: 0.32
# 1/1 [==============================] - 0s 55ms/step
# ISIC_3114484.jpg: Predicted class: Benign
# Probability: 0.46
# 1/1 [==============================] - 0s 56ms/step
# ISIC_4591934.jpg: Predicted class: Benign
# Probability: 0.39
# 1/1 [==============================] - 0s 56ms/step
# ISIC_4249430.jpg: Predicted class: Benign
# Probability: 0.06
# 1/1 [==============================] - 0s 58ms/step
# ISIC_8100969.jpg: Predicted class: Benign
# Probability: 0.23
# 1/1 [==============================] - 0s 90ms/step
# ISIC_8753442.jpg: Predicted class: Benign
# Probability: 0.07
# 1/1 [==============================] - 0s 89ms/step
# ISIC_7695262.jpg: Predicted class: Benign
# Probability: 0.05
# 1/1 [==============================] - 0s 58ms/step
# ISIC_1682504.jpg: Predicted class: Benign
# Probability: 0.27
# 1/1 [==============================] - 0s 56ms/step
# ISIC_5573288.jpg: Predicted class: Benign
# Probability: 0.12
# 1/1 [==============================] - 0s 57ms/step
# ISIC_9207601.jpg: Predicted class: Benign
# Probability: 0.04
# 1/1 [==============================] - 0s 54ms/step
# ISIC_1889661.jpg: Predicted class: Benign
# Probability: 0.45
# 1/1 [==============================] - 0s 56ms/step
# ISIC_7785460.jpg: Predicted class: Benign
# Probability: 0.27
# 1/1 [==============================] - 0s 91ms/step
# ISIC_9869618.jpg: Predicted class: Malignant
# Probability: 0.72
# 1/1 [==============================] - 0s 107ms/step
# ISIC_6561559.jpg: Predicted class: Benign
# Probability: 0.19
# 1/1 [==============================] - 0s 94ms/step
# ISIC_4060128.jpg: Predicted class: Benign
# Probability: 0.10
# 1/1 [==============================] - 0s 57ms/step
# ISIC_8962966.jpg: Predicted class: Benign
# Probability: 0.13
# 1/1 [==============================] - 0s 56ms/step
# ISIC_6942800.jpg: Predicted class: Benign
# Probability: 0.17
# 1/1 [==============================] - 0s 57ms/step
# ISIC_8425779.jpg: Predicted class: Malignant
# Probability: 0.64
# 1/1 [==============================] - 0s 58ms/step
# ISIC_6598283.jpg: Predicted class: Malignant
# Probability: 0.53
# 1/1 [==============================] - 0s 64ms/step
# ISIC_7236531.jpg: Predicted class: Benign
# Probability: 0.39
# 1/1 [==============================] - 0s 60ms/step
# ISIC_2611496.jpg: Predicted class: Benign
# Probability: 0.08
# 1/1 [==============================] - 0s 59ms/step
# ISIC_7208452.jpg: Predicted class: Malignant
# Probability: 0.69
# 1/1 [==============================] - 0s 77ms/step
# ISIC_9758068.jpg: Predicted class: Benign
# Probability: 0.42
# 1/1 [==============================] - 0s 62ms/step
# ISIC_4798580.jpg: Predicted class: Benign
# Probability: 0.19
# 1/1 [==============================] - 0s 94ms/step
# ISIC_0756977.jpg: Predicted class: Benign
# Probability: 0.39
# 1/1 [==============================] - 0s 86ms/step
# ISIC_3331297.jpg: Predicted class: Benign
# Probability: 0.48
# 1/1 [==============================] - 0s 89ms/step
# ISIC_5209191.jpg: Predicted class: Benign
# Probability: 0.46
# 1/1 [==============================] - 0s 100ms/step
# ISIC_5998628.jpg: Predicted class: Benign
# Probability: 0.06
# 1/1 [==============================] - 0s 55ms/step
# ISIC_1289443.jpg: Predicted class: Benign
# Probability: 0.09
# 1/1 [==============================] - 0s 71ms/step
# ISIC_4990272.jpg: Predicted class: Benign
# Probability: 0.08
# 1/1 [==============================] - 0s 59ms/step
# ISIC_5143609.jpg: Predicted class: Malignant
# Probability: 0.83
# 1/1 [==============================] - 0s 57ms/step
# ISIC_3357803.jpg: Predicted class: Benign
# Probability: 0.40
# 1/1 [==============================] - 0s 58ms/step
# ISIC_9530345.jpg: Predicted class: Benign
# Probability: 0.14
# 1/1 [==============================] - 0s 69ms/step
# ISIC_1063577.jpg: Predicted class: Malignant
# Probability: 0.71
# 1/1 [==============================] - 0s 62ms/step
# ISIC_6066866.jpg: Predicted class: Benign
# Probability: 0.17
# 1/1 [==============================] - 0s 57ms/step
# ISIC_5500783.jpg: Predicted class: Benign
# Probability: 0.23
# 1/1 [==============================] - 0s 58ms/step
# ISIC_7102456.jpg: Predicted class: Benign
# Probability: 0.19
# 1/1 [==============================] - 0s 97ms/step
# ISIC_0674308.jpg: Predicted class: Malignant
# Probability: 0.67
# 1/1 [==============================] - 0s 94ms/step
# ISIC_1410574.jpg: Predicted class: Benign
# Probability: 0.04
# 1/1 [==============================] - 0s 59ms/step
# ISIC_4734602.jpg: Predicted class: Benign
# Probability: 0.11
# 1/1 [==============================] - 0s 66ms/step
# ISIC_2287895.jpg: Predicted class: Malignant
# Probability: 0.59
# 1/1 [==============================] - 0s 60ms/step
# ISIC_1291312.jpg: Predicted class: Benign
# Probability: 0.34
# 1/1 [==============================] - 0s 62ms/step
# ISIC_3118476.jpg: Predicted class: Benign
# Probability: 0.11
# 1/1 [==============================] - 0s 57ms/step
# ISIC_7133530.jpg: Predicted class: Benign
# Probability: 0.41
# 1/1 [==============================] - 0s 68ms/step
# ISIC_1491444.jpg: Predicted class: Malignant
# Probability: 0.67
# 1/1 [==============================] - 0s 56ms/step
# ISIC_4185567.jpg: Predicted class: Malignant
# Probability: 0.71
# 1/1 [==============================] - 0s 56ms/step
# ISIC_7921623.jpg: Predicted class: Benign
# Probability: 0.26
# 1/1 [==============================] - 0s 58ms/step
# ISIC_8012767.jpg: Predicted class: Benign
# Probability: 0.09
# 1/1 [==============================] - 0s 65ms/step
# ISIC_0786267.jpg: Predicted class: Benign
# Probability: 0.29
# 1/1 [==============================] - 0s 64ms/step
# ISIC_8313489.jpg: Predicted class: Malignant
# Probability: 0.72
# 1/1 [==============================] - 0s 60ms/step
# ISIC_4435605.jpg: Predicted class: Malignant
# Probability: 0.52
# 1/1 [==============================] - 0s 91ms/step
# ISIC_5275484.jpg: Predicted class: Benign
# Probability: 0.05
# 1/1 [==============================] - 0s 98ms/step
# ISIC_4502147.jpg: Predicted class: Benign
# Probability: 0.06
# 1/1 [==============================] - 0s 108ms/step
# ISIC_2256559.jpg: Predicted class: Benign
# Probability: 0.18
# 1/1 [==============================] - 0s 58ms/step
# ISIC_5955496.jpg: Predicted class: Benign
# Probability: 0.09
# 1/1 [==============================] - 0s 91ms/step
# ISIC_7349770.jpg: Predicted class: Benign
# Probability: 0.48
# 1/1 [==============================] - 0s 94ms/step
# ISIC_8895569.jpg: Predicted class: Malignant
# Probability: 0.82
# 1/1 [==============================] - 0s 60ms/step
# ISIC_7425333.jpg: Predicted class: Benign
# Probability: 0.45
# 1/1 [==============================] - 0s 59ms/step
# ISIC_3205782.jpg: Predicted class: Benign
# Probability: 0.05
# 1/1 [==============================] - 0s 66ms/step
# ISIC_4703373.jpg: Predicted class: Malignant
# Probability: 0.91
# 1/1 [==============================] - 0s 59ms/step
# ISIC_5011656.jpg: Predicted class: Benign
# Probability: 0.11
# 1/1 [==============================] - 0s 57ms/step
# ISIC_3057622.jpg: Predicted class: Benign
# Probability: 0.05
# 1/1 [==============================] - 0s 93ms/step
# ISIC_3025179.jpg: Predicted class: Benign
# Probability: 0.08
# 1/1 [==============================] - 0s 98ms/step
# ISIC_4399932.jpg: Predicted class: Benign
# Probability: 0.47
# 1/1 [==============================] - 0s 94ms/step
# ISIC_5297738.jpg: Predicted class: Benign
# Probability: 0.11
# 1/1 [==============================] - 0s 58ms/step
# ISIC_8362547.jpg: Predicted class: Benign
# Probability: 0.23
# 1/1 [==============================] - 0s 58ms/step
# ISIC_6948933.jpg: Predicted class: Malignant
# Probability: 0.61
# 1/1 [==============================] - 0s 58ms/step
# ISIC_7553317.jpg: Predicted class: Benign
# Probability: 0.06
# 1/1 [==============================] - 0s 69ms/step
# ISIC_1134428.jpg: Predicted class: Benign
# Probability: 0.14
# 1/1 [==============================] - 0s 63ms/step
# ISIC_2222926.jpg: Predicted class: Malignant
# Probability: 0.65
# 1/1 [==============================] - 0s 56ms/step
# ISIC_7310710.jpg: Predicted class: Benign
# Probability: 0.04
# 1/1 [==============================] - 0s 56ms/step
# ISIC_3713204.jpg: Predicted class: Benign
# Probability: 0.17
# 1/1 [==============================] - 0s 66ms/step
# ISIC_8965024.jpg: Predicted class: Malignant
# Probability: 0.71
# 1/1 [==============================] - 0s 131ms/step
# ISIC_8549378.jpg: Predicted class: Benign
# Probability: 0.06
# 1/1 [==============================] - 0s 135ms/step
# ISIC_7007108.jpg: Predicted class: Malignant
# Probability: 0.68
# 1/1 [==============================] - 0s 62ms/step
# ISIC_7737938.jpg: Predicted class: Benign
# Probability: 0.21
# 1/1 [==============================] - 0s 65ms/step
# ISIC_9895171.jpg: Predicted class: Benign
# Probability: 0.32
# 1/1 [==============================] - 0s 63ms/step
# ISIC_4194768.jpg: Predicted class: Benign
# Probability: 0.09
# 1/1 [==============================] - 0s 57ms/step
# ISIC_9734753.jpg: Predicted class: Benign
# Probability: 0.28
# 1/1 [==============================] - 0s 57ms/step
# ISIC_8829628.jpg: Predicted class: Benign
# Probability: 0.06
# 1/1 [==============================] - 0s 58ms/step
# ISIC_4719774.jpg: Predicted class: Benign
# Probability: 0.20
# 1/1 [==============================] - 0s 60ms/step
# ISIC_7186817.jpg: Predicted class: Malignant
# Probability: 0.66
# 1/1 [==============================] - 0s 62ms/step
# ISIC_1111490.jpg: Predicted class: Benign
# Probability: 0.09
# 1/1 [==============================] - 0s 59ms/step
# ISIC_1708417.jpg: Predicted class: Benign
# Probability: 0.23
# 1/1 [==============================] - 0s 89ms/step
# ISIC_4564430.jpg: Predicted class: Benign
# Probability: 0.16
# 1/1 [==============================] - 0s 94ms/step
# ISIC_6712374.jpg: Predicted class: Benign
# Probability: 0.48
# 1/1 [==============================] - 0s 105ms/step
# ISIC_5752353.jpg: Predicted class: Benign
# Probability: 0.01
# 1/1 [==============================] - 0s 93ms/step
# ISIC_4282399.jpg: Predicted class: Malignant
# Probability: 0.98
# 1/1 [==============================] - 0s 63ms/step
# ISIC_2559237.jpg: Predicted class: Benign
# Probability: 0.05
# 1/1 [==============================] - 0s 59ms/step
# ISIC_4864264.jpg: Predicted class: Benign
# Probability: 0.34
# 1/1 [==============================] - 0s 69ms/step
# ISIC_5447745.jpg: Predicted class: Benign
# Probability: 0.27
# 1/1 [==============================] - 0s 57ms/step
# ISIC_8718545.jpg: Predicted class: Benign
# Probability: 0.07
# 1/1 [==============================] - 0s 58ms/step
# ISIC_6976452.jpg: Predicted class: Benign
# Probability: 0.08
# 1/1 [==============================] - 0s 57ms/step
# ISIC_8103951.jpg: Predicted class: Benign
# Probability: 0.06
# 1/1 [==============================] - 0s 59ms/step
# ISIC_6570876.jpg: Predicted class: Benign
# Probability: 0.15
# 1/1 [==============================] - 0s 55ms/step
# ISIC_5763997.jpg: Predicted class: Benign
# Probability: 0.12
# 1/1 [==============================] - 0s 67ms/step
# ISIC_5379701.jpg: Predicted class: Malignant
# Probability: 0.80
# 1/1 [==============================] - 0s 93ms/step
# ISIC_6952589.jpg: Predicted class: Benign
# Probability: 0.05
# 1/1 [==============================] - 0s 96ms/step
# ISIC_8223262.jpg: Predicted class: Benign
# Probability: 0.04
# 1/1 [==============================] - 0s 88ms/step
# ISIC_2802301.jpg: Predicted class: Benign
# Probability: 0.21
# 1/1 [==============================] - 0s 59ms/step
# ISIC_1916336.jpg: Predicted class: Malignant
# Probability: 0.64
# 1/1 [==============================] - 0s 57ms/step
# ISIC_1612523.jpg: Predicted class: Benign
# Probability: 0.09
# 1/1 [==============================] - 0s 58ms/step
# ISIC_0268451.jpg: Predicted class: Benign
# Probability: 0.38
# 1/1 [==============================] - 0s 58ms/step
# ISIC_7848111.jpg: Predicted class: Malignant
# Probability: 0.58
# 1/1 [==============================] - 0s 55ms/step
# ISIC_4365909.jpg: Predicted class: Benign
# Probability: 0.15
# 1/1 [==============================] - 0s 58ms/step
# ISIC_5006243.jpg: Predicted class: Malignant
# Probability: 0.75
# 1/1 [==============================] - 0s 56ms/step
# ISIC_4964804.jpg: Predicted class: Malignant
# Probability: 0.52
# 1/1 [==============================] - 0s 55ms/step
# ISIC_6122007.jpg: Predicted class: Benign
# Probability: 0.11
# 1/1 [==============================] - 0s 97ms/step
# ISIC_4198983.jpg: Predicted class: Benign
# Probability: 0.08
# 1/1 [==============================] - 0s 95ms/step
# ISIC_1326532.jpg: Predicted class: Benign
# Probability: 0.02
# 1/1 [==============================] - 0s 97ms/step
# ISIC_1516113.jpg: Predicted class: Malignant
# Probability: 0.54
# 1/1 [==============================] - 0s 60ms/step
# ISIC_5725417.jpg: Predicted class: Malignant
# Probability: 0.66
# 1/1 [==============================] - 0s 58ms/step
# ISIC_9047445.jpg: Predicted class: Benign
# Probability: 0.35
# 1/1 [==============================] - 0s 57ms/step
# ISIC_8209167.jpg: Predicted class: Benign
# Probability: 0.29
# 1/1 [==============================] - 0s 61ms/step
# ISIC_5943122.jpg: Predicted class: Benign
# Probability: 0.27
# 1/1 [==============================] - 0s 57ms/step
# ISIC_1438138.jpg: Predicted class: Benign
# Probability: 0.40
# 1/1 [==============================] - 0s 58ms/step
# ISIC_8224453.jpg: Predicted class: Benign
# Probability: 0.35
# 1/1 [==============================] - 0s 58ms/step
# ISIC_7475644.jpg: Predicted class: Malignant
# Probability: 0.61
# 1/1 [==============================] - 0s 58ms/step
# ISIC_8405160.jpg: Predicted class: Malignant
# Probability: 0.78
# 1/1 [==============================] - 0s 58ms/step
# ISIC_8445182.jpg: Predicted class: Benign
# Probability: 0.10
# 1/1 [==============================] - 0s 90ms/step
# ISIC_6390348.jpg: Predicted class: Malignant
# Probability: 0.74
# 1/1 [==============================] - 0s 96ms/step
# ISIC_5120471.jpg: Predicted class: Benign
# Probability: 0.30
# 1/1 [==============================] - 0s 73ms/step
# ISIC_3119515.jpg: Predicted class: Benign
# Probability: 0.28
# 1/1 [==============================] - 0s 56ms/step
# ISIC_7113993.jpg: Predicted class: Benign
# Probability: 0.49
# 1/1 [==============================] - 0s 57ms/step
# ISIC_9341631.jpg: Predicted class: Benign
# Probability: 0.30
# 1/1 [==============================] - 0s 57ms/step
# ISIC_3710566.jpg: Predicted class: Benign
# Probability: 0.35
# 1/1 [==============================] - 0s 57ms/step
# ISIC_9509950.jpg: Predicted class: Benign
# Probability: 0.23
# 1/1 [==============================] - 0s 57ms/step
# ISIC_4044509.jpg: Predicted class: Benign
# Probability: 0.34
# 1/1 [==============================] - 0s 61ms/step
# ISIC_6544818.jpg: Predicted class: Benign
# Probability: 0.19
# 1/1 [==============================] - 0s 60ms/step
# ISIC_5290070.jpg: Predicted class: Malignant
# Probability: 0.71
# 1/1 [==============================] - 0s 59ms/step
# ISIC_1149878.jpg: Predicted class: Benign
# Probability: 0.15
# 1/1 [==============================] - 0s 88ms/step
# ISIC_8110338.jpg: Predicted class: Benign
# Probability: 0.26
# 1/1 [==============================] - 0s 92ms/step
# ISIC_7863462.jpg: Predicted class: Benign
# Probability: 0.09
# 1/1 [==============================] - 0s 57ms/step
# ISIC_9020615.jpg: Predicted class: Benign
# Probability: 0.26
# 1/1 [==============================] - 0s 70ms/step
# ISIC_4137383.jpg: Predicted class: Benign
# Probability: 0.02
# 1/1 [==============================] - 0s 58ms/step
# ISIC_9973102.jpg: Predicted class: Benign
# Probability: 0.27
# 1/1 [==============================] - 0s 57ms/step
# ISIC_7841575.jpg: Predicted class: Malignant
# Probability: 0.54
# 1/1 [==============================] - 0s 61ms/step
# ISIC_1693659.jpg: Predicted class: Benign
# Probability: 0.04
# 1/1 [==============================] - 0s 73ms/step
# ISIC_5972909.jpg: Predicted class: Malignant
# Probability: 0.55
# 1/1 [==============================] - 0s 67ms/step
# ISIC_2650588.jpg: Predicted class: Benign
# Probability: 0.47
# 1/1 [==============================] - 0s 60ms/step
# ISIC_7936809.jpg: Predicted class: Malignant
# Probability: 0.65
# 1/1 [==============================] - 0s 96ms/step
# ISIC_6977916.jpg: Predicted class: Benign
# Probability: 0.30
# 1/1 [==============================] - 0s 91ms/step
# ISIC_7656837.jpg: Predicted class: Benign
# Probability: 0.20
# 1/1 [==============================] - 0s 90ms/step
# ISIC_8253521.jpg: Predicted class: Benign
# Probability: 0.38
# 1/1 [==============================] - 0s 61ms/step
# ISIC_2382928.jpg: Predicted class: Benign
# Probability: 0.11
# 1/1 [==============================] - 0s 72ms/step
# ISIC_6019530.jpg: Predicted class: Benign
# Probability: 0.32
# 1/1 [==============================] - 0s 59ms/step
# ISIC_4746727.jpg: Predicted class: Benign
# Probability: 0.10
# 1/1 [==============================] - 0s 67ms/step
# ISIC_0724784.jpg: Predicted class: Benign
# Probability: 0.06
# 1/1 [==============================] - 0s 58ms/step
# ISIC_6295805.jpg: Predicted class: Malignant
# Probability: 0.69
# 1/1 [==============================] - 0s 57ms/step
# ISIC_9174552.jpg: Predicted class: Malignant
# Probability: 0.84
# 1/1 [==============================] - 0s 68ms/step
# ISIC_6903770.jpg: Predicted class: Malignant
# Probability: 0.80
# 1/1 [==============================] - 0s 63ms/step
# ISIC_3373821.jpg: Predicted class: Benign
# Probability: 0.11
# 1/1 [==============================] - 0s 62ms/step
# ISIC_2883756.jpg: Predicted class: Malignant
# Probability: 0.86
# 1/1 [==============================] - 0s 62ms/step
# ISIC_0990463.jpg: Predicted class: Benign
# Probability: 0.41
# 1/1 [==============================] - 0s 56ms/step
# ISIC_4311189.jpg: Predicted class: Benign
# Probability: 0.42
# 1/1 [==============================] - 0s 99ms/step
# ISIC_9419168.jpg: Predicted class: Benign
# Probability: 0.02
# 1/1 [==============================] - 0s 56ms/step
# ISIC_7022319.jpg: Predicted class: Benign
# Probability: 0.04
# 1/1 [==============================] - 0s 57ms/step
# ISIC_0772706.jpg: Predicted class: Benign
# Probability: 0.25
# 1/1 [==============================] - 0s 58ms/step
# ISIC_7192464.jpg: Predicted class: Benign
# Probability: 0.08
# 1/1 [==============================] - 0s 55ms/step
# ISIC_4584886.jpg: Predicted class: Malignant
# Probability: 0.60
# 1/1 [==============================] - 0s 59ms/step
# ISIC_4265022.jpg: Predicted class: Benign
# Probability: 0.42
# 1/1 [==============================] - 0s 59ms/step
# ISIC_8459597.jpg: Predicted class: Malignant
# Probability: 0.77
# 1/1 [==============================] - 0s 57ms/step
# ISIC_2251334.jpg: Predicted class: Benign
# Probability: 0.13
# 1/1 [==============================] - 0s 57ms/step
# ISIC_6441462.jpg: Predicted class: Benign
# Probability: 0.37
# 1/1 [==============================] - 0s 59ms/step
# ISIC_1637595.jpg: Predicted class: Benign
# Probability: 0.18
# 1/1 [==============================] - 0s 97ms/step
# ISIC_6850984.jpg: Predicted class: Benign
# Probability: 0.15
# 1/1 [==============================] - 0s 92ms/step
# ISIC_2539351.jpg: Predicted class: Malignant
# Probability: 0.73
# 1/1 [==============================] - 0s 60ms/step
# ISIC_3243743.jpg: Predicted class: Benign
# Probability: 0.42
# 1/1 [==============================] - 0s 59ms/step
# ISIC_8532615.jpg: Predicted class: Malignant
# Probability: 0.70
# 1/1 [==============================] - 0s 71ms/step
# ISIC_6620053.jpg: Predicted class: Benign
# Probability: 0.18
# 1/1 [==============================] - 0s 59ms/step
# ISIC_3689121.jpg: Predicted class: Malignant
# Probability: 0.95
# 1/1 [==============================] - 0s 56ms/step
# ISIC_2377475.jpg: Predicted class: Malignant
# Probability: 0.68
# 1/1 [==============================] - 0s 58ms/step
# ISIC_6744070.jpg: Predicted class: Malignant
# Probability: 0.95
# 1/1 [==============================] - 0s 93ms/step
# ISIC_7270195.jpg: Predicted class: Benign
# Probability: 0.15
# 1/1 [==============================] - 0s 64ms/step
# ISIC_1435661.jpg: Predicted class: Benign
# Probability: 0.07
# 1/1 [==============================] - 0s 94ms/step
# ISIC_1790991.jpg: Predicted class: Benign
# Probability: 0.22
# 1/1 [==============================] - 0s 97ms/step
# ISIC_4818265.jpg: Predicted class: Benign
# Probability: 0.07
# 1/1 [==============================] - 0s 58ms/step
# ISIC_6324738.jpg: Predicted class: Benign
# Probability: 0.13
# 1/1 [==============================] - 0s 61ms/step
# ISIC_5900599.jpg: Predicted class: Benign
# Probability: 0.11
# 1/1 [==============================] - 0s 68ms/step
# ISIC_5446229.jpg: Predicted class: Benign
# Probability: 0.48
# 1/1 [==============================] - 0s 58ms/step
# ISIC_2737135.jpg: Predicted class: Benign
# Probability: 0.37
# 1/1 [==============================] - 0s 64ms/step
# ISIC_2761222.jpg: Predicted class: Benign
# Probability: 0.04
# 1/1 [==============================] - 0s 88ms/step
# ISIC_4005292.jpg: Predicted class: Benign
# Probability: 0.18
# 1/1 [==============================] - 0s 100ms/step
# ISIC_7636842.jpg: Predicted class: Malignant
# Probability: 0.58
# 1/1 [==============================] - 0s 79ms/step
# ISIC_4195928.jpg: Predicted class: Malignant
# Probability: 0.58
# 1/1 [==============================] - 0s 55ms/step
# ISIC_5627557.jpg: Predicted class: Benign
# Probability: 0.17
# 1/1 [==============================] - 0s 57ms/step
# ISIC_8444333.jpg: Predicted class: Benign
# Probability: 0.00
# 1/1 [==============================] - 0s 58ms/step
# ISIC_6418859.jpg: Predicted class: Benign
# Probability: 0.05
# 1/1 [==============================] - 0s 56ms/step
# ISIC_2995868.jpg: Predicted class: Malignant
# Probability: 0.93
# 1/1 [==============================] - 0s 58ms/step
# ISIC_7143554.jpg: Predicted class: Benign
# Probability: 0.28
# 1/1 [==============================] - 0s 62ms/step
# ISIC_2726427.jpg: Predicted class: Malignant
# Probability: 0.77
# 1/1 [==============================] - 0s 65ms/step
# ISIC_8876387.jpg: Predicted class: Benign
# Probability: 0.17
# 1/1 [==============================] - 0s 70ms/step
# ISIC_5638807.jpg: Predicted class: Benign
# Probability: 0.22
# 1/1 [==============================] - 0s 66ms/step
# ISIC_3004536.jpg: Predicted class: Malignant
# Probability: 0.71
# 1/1 [==============================] - 0s 85ms/step
# ISIC_0148210.jpg: Predicted class: Benign
# Probability: 0.15
# 1/1 [==============================] - 0s 94ms/step
# ISIC_0468644.jpg: Predicted class: Benign
# Probability: 0.07
# 1/1 [==============================] - 0s 96ms/step
# ISIC_4078377.jpg: Predicted class: Benign
# Probability: 0.04
# 1/1 [==============================] - 0s 60ms/step
# ISIC_6656423.jpg: Predicted class: Benign
# Probability: 0.06
# 1/1 [==============================] - 0s 57ms/step
# ISIC_2160245.jpg: Predicted class: Benign
# Probability: 0.05
# 1/1 [==============================] - 0s 59ms/step
# ISIC_1799448.jpg: Predicted class: Benign
# Probability: 0.43
# 1/1 [==============================] - 0s 58ms/step
# ISIC_3744890.jpg: Predicted class: Benign
# Probability: 0.18
# 1/1 [==============================] - 0s 62ms/step
# ISIC_5972532.jpg: Predicted class: Benign
# Probability: 0.18
# 1/1 [==============================] - 0s 61ms/step
# ISIC_6036423.jpg: Predicted class: Benign
# Probability: 0.27
# 1/1 [==============================] - 0s 54ms/step
# ISIC_7132047.jpg: Predicted class: Benign
# Probability: 0.11
# 1/1 [==============================] - 0s 91ms/step
# ISIC_0464417.jpg: Predicted class: Benign
# Probability: 0.06
# 1/1 [==============================] - 0s 97ms/step
# ISIC_3222250.jpg: Predicted class: Benign
# Probability: 0.18
# 1/1 [==============================] - 0s 56ms/step
# ISIC_3169710.jpg: Predicted class: Benign
# Probability: 0.12
# 1/1 [==============================] - 0s 57ms/step
# ISIC_1153749.jpg: Predicted class: Benign
# Probability: 0.22
# 1/1 [==============================] - 0s 57ms/step
# ISIC_3265972.jpg: Predicted class: Benign
# Probability: 0.05
# 1/1 [==============================] - 0s 60ms/step
# ISIC_6735214.jpg: Predicted class: Benign
# Probability: 0.38
# 1/1 [==============================] - 0s 58ms/step
# ISIC_8386959.jpg: Predicted class: Benign
# Probability: 0.05
# 1/1 [==============================] - 0s 62ms/step
# ISIC_4119334.jpg: Predicted class: Benign
# Probability: 0.03
# 1/1 [==============================] - 0s 77ms/step
# ISIC_7263763.jpg: Predicted class: Benign
# Probability: 0.07
# 1/1 [==============================] - 0s 95ms/step
# ISIC_8200860.jpg: Predicted class: Benign
# Probability: 0.17
# 1/1 [==============================] - 0s 96ms/step
# ISIC_9424811.jpg: Predicted class: Benign
# Probability: 0.33
# 1/1 [==============================] - 0s 67ms/step
# ISIC_2302436.jpg: Predicted class: Malignant
# Probability: 0.90
# 1/1 [==============================] - 0s 59ms/step
# ISIC_3697615.jpg: Predicted class: Malignant
# Probability: 0.91
# 1/1 [==============================] - 0s 58ms/step
# ISIC_7877822.jpg: Predicted class: Malignant
# Probability: 0.51
# 1/1 [==============================] - 0s 59ms/step
# ISIC_3834484.jpg: Predicted class: Benign
# Probability: 0.15
# 1/1 [==============================] - 0s 68ms/step
# ISIC_4881393.jpg: Predicted class: Benign
# Probability: 0.44
# 1/1 [==============================] - 0s 56ms/step
# ISIC_0989319.jpg: Predicted class: Benign
# Probability: 0.05
# 1/1 [==============================] - 0s 56ms/step
# ISIC_9109293.jpg: Predicted class: Malignant
# Probability: 0.71
# 1/1 [==============================] - 0s 58ms/step
# ISIC_2568399.jpg: Predicted class: Benign
# Probability: 0.36
# 1/1 [==============================] - 0s 80ms/step
# ISIC_0681019.jpg: Predicted class: Malignant
# Probability: 0.79
# 1/1 [==============================] - 0s 95ms/step
# ISIC_4537689.jpg: Predicted class: Benign
# Probability: 0.08
# 1/1 [==============================] - 0s 89ms/step
# ISIC_8531444.jpg: Predicted class: Benign
# Probability: 0.24
# 1/1 [==============================] - 0s 94ms/step
# ISIC_4204071.jpg: Predicted class: Benign
# Probability: 0.24
# 1/1 [==============================] - 0s 58ms/step
# ISIC_9237342.jpg: Predicted class: Malignant
# Probability: 0.78
# 1/1 [==============================] - 0s 57ms/step
# ISIC_4566970.jpg: Predicted class: Benign
# Probability: 0.43
# 1/1 [==============================] - 0s 56ms/step
# ISIC_8010841.jpg: Predicted class: Benign
# Probability: 0.25
# 1/1 [==============================] - 0s 63ms/step
# ISIC_7522882.jpg: Predicted class: Benign
# Probability: 0.04
# 1/1 [==============================] - 0s 56ms/step
# ISIC_3582780.jpg: Predicted class: Benign
# Probability: 0.32
# 1/1 [==============================] - 0s 57ms/step
# ISIC_8991162.jpg: Predicted class: Malignant
# Probability: 0.79
# 1/1 [==============================] - 0s 63ms/step
# ISIC_2691534.jpg: Predicted class: Benign
# Probability: 0.15
# 1/1 [==============================] - 0s 61ms/step
# ISIC_2717613.jpg: Predicted class: Benign
# Probability: 0.21
# 1/1 [==============================] - 0s 62ms/step
# ISIC_8942163.jpg: Predicted class: Benign
# Probability: 0.37
# 1/1 [==============================] - 0s 103ms/step
# ISIC_4430138.jpg: Predicted class: Benign
# Probability: 0.24
# 1/1 [==============================] - 0s 92ms/step
# ISIC_1437627.jpg: Predicted class: Benign
# Probability: 0.12
# 1/1 [==============================] - 0s 95ms/step
# ISIC_7511353.jpg: Predicted class: Malignant
# Probability: 0.88
# 1/1 [==============================] - 0s 56ms/step
# ISIC_1899151.jpg: Predicted class: Malignant
# Probability: 0.78
# 1/1 [==============================] - 0s 57ms/step
# ISIC_5496072.jpg: Predicted class: Benign
# Probability: 0.14
# 1/1 [==============================] - 0s 61ms/step
# ISIC_3393209.jpg: Predicted class: Benign
# Probability: 0.02
# 1/1 [==============================] - 0s 55ms/step
# ISIC_1131265.jpg: Predicted class: Benign
# Probability: 0.13
# 1/1 [==============================] - 0s 60ms/step
# ISIC_2955552.jpg: Predicted class: Malignant
# Probability: 0.83
# 1/1 [==============================] - 0s 62ms/step
# ISIC_7830532.jpg: Predicted class: Benign
# Probability: 0.04
# 1/1 [==============================] - 0s 66ms/step
# ISIC_0874773.jpg: Predicted class: Malignant
# Probability: 0.54
# 1/1 [==============================] - 0s 61ms/step
# ISIC_8574400.jpg: Predicted class: Benign
# Probability: 0.08
# 1/1 [==============================] - 0s 57ms/step
# ISIC_6272978.jpg: Predicted class: Malignant
# Probability: 0.82
# 1/1 [==============================] - 0s 65ms/step
# ISIC_2126077.jpg: Predicted class: Benign
# Probability: 0.24
# 1/1 [==============================] - 0s 91ms/step
# ISIC_4621173.jpg: Predicted class: Benign
# Probability: 0.04
# 1/1 [==============================] - 0s 93ms/step
# ISIC_4953789.jpg: Predicted class: Benign
# Probability: 0.20
# 1/1 [==============================] - 0s 56ms/step
# ISIC_8930106.jpg: Predicted class: Benign
# Probability: 0.27
# 1/1 [==============================] - 0s 62ms/step
# ISIC_8155289.jpg: Predicted class: Malignant
# Probability: 0.64
# 1/1 [==============================] - 0s 70ms/step
# ISIC_8432957.jpg: Predicted class: Benign
# Probability: 0.32
# 1/1 [==============================] - 0s 57ms/step
# ISIC_1426190.jpg: Predicted class: Benign
# Probability: 0.04
# 1/1 [==============================] - 0s 55ms/step
# ISIC_7653459.jpg: Predicted class: Benign
# Probability: 0.04
# 1/1 [==============================] - 0s 93ms/step
# ISIC_8159272.jpg: Predicted class: Benign
# Probability: 0.19
# 1/1 [==============================] - 0s 96ms/step
# ISIC_5154074.jpg: Predicted class: Benign
# Probability: 0.04
# 1/1 [==============================] - 0s 94ms/step
# ISIC_4841875.jpg: Predicted class: Benign
# Probability: 0.05
# 1/1 [==============================] - 0s 58ms/step
# ISIC_0674769.jpg: Predicted class: Malignant
# Probability: 0.51
# 1/1 [==============================] - 0s 59ms/step
# ISIC_2578562.jpg: Predicted class: Malignant
# Probability: 0.90
# 1/1 [==============================] - 0s 59ms/step
# ISIC_8935177.jpg: Predicted class: Benign
# Probability: 0.29
# 1/1 [==============================] - 0s 58ms/step
# ISIC_0946365.jpg: Predicted class: Benign
# Probability: 0.32
# 1/1 [==============================] - 0s 61ms/step
# ISIC_7135160.jpg: Predicted class: Malignant
# Probability: 0.94
# 1/1 [==============================] - 0s 59ms/step
# ISIC_8802849.jpg: Predicted class: Benign
# Probability: 0.03
# 1/1 [==============================] - 0s 60ms/step
# ISIC_5628761.jpg: Predicted class: Benign
# Probability: 0.31
# 1/1 [==============================] - 0s 66ms/step
# ISIC_8294587.jpg: Predicted class: Malignant
# Probability: 0.62
# 1/1 [==============================] - 0s 66ms/step
# ISIC_5892469.jpg: Predicted class: Benign
# Probability: 0.01
# 1/1 [==============================] - 0s 56ms/step
# ISIC_8344285.jpg: Predicted class: Malignant
# Probability: 0.78
# 1/1 [==============================] - 0s 63ms/step
# ISIC_5631948.jpg: Predicted class: Benign
# Probability: 0.48
# 1/1 [==============================] - 0s 93ms/step
# ISIC_5789959.jpg: Predicted class: Malignant
# Probability: 0.59
# 1/1 [==============================] - 0s 57ms/step
# ISIC_8776327.jpg: Predicted class: Benign
# Probability: 0.10
# 1/1 [==============================] - 0s 58ms/step
# ISIC_8020026.jpg: Predicted class: Malignant
# Probability: 0.61
# 1/1 [==============================] - 0s 59ms/step
# ISIC_2408338.jpg: Predicted class: Benign
# Probability: 0.18
# 1/1 [==============================] - 0s 65ms/step
# ISIC_9705000.jpg: Predicted class: Benign
# Probability: 0.03
# 1/1 [==============================] - 0s 61ms/step
# ISIC_7141412.jpg: Predicted class: Benign
# Probability: 0.01
# 1/1 [==============================] - 0s 61ms/step
# ISIC_8429000.jpg: Predicted class: Benign
# Probability: 0.21
# 1/1 [==============================] - 0s 68ms/step
# ISIC_1222096.jpg: Predicted class: Benign
# Probability: 0.08
# 1/1 [==============================] - 0s 56ms/step
# ISIC_0183658.jpg: Predicted class: Benign
# Probability: 0.06
# 1/1 [==============================] - 0s 59ms/step
# ISIC_6579000.jpg: Predicted class: Benign
# Probability: 0.27
# 1/1 [==============================] - 0s 93ms/step
# ISIC_6740393.jpg: Predicted class: Benign
# Probability: 0.32
# 1/1 [==============================] - 0s 109ms/step
# ...
# ISIC_0244885.jpg: Predicted class: Benign
# Probability: 0.23
# 1/1 [==============================] - 0s 59ms/step
# ISIC_8332544.jpg: Predicted class: Malignant
# Probability: 0.56
# 1/1 [==============================] - 0s 58ms/step
# ISIC_9948144.jpg: Predicted class: Benign
# Probability: 0.13
# 1/1 [==============================] - 0s 63ms/step
# ISIC_7011312.jpg: Predicted class: Benign
# Probability: 0.29
# 1/1 [==============================] - 0s 59ms/step
# ISIC_3718570.jpg: Predicted class: Benign
# Probability: 0.15
# 1/1 [==============================] - 0s 56ms/step
# ISIC_3249625.jpg: Predicted class: Malignant
# Probability: 0.75
# 1/1 [==============================] - 0s 99ms/step
# ISIC_4939110.jpg: Predicted class: Benign
# Probability: 0.20
# 1/1 [==============================] - 0s 102ms/step
# ISIC_4864699.jpg: Predicted class: Malignant
# Probability: 0.53
# 1/1 [==============================] - 0s 93ms/step
# ISIC_7361481.jpg: Predicted class: Malignant
# Probability: 0.51
# 1/1 [==============================] - 0s 56ms/step
# ISIC_4494730.jpg: Predicted class: Benign
# Probability: 0.15
# 1/1 [==============================] - 0s 61ms/step
# ISIC_1642626.jpg: Predicted class: Benign
# Probability: 0.22
# 1/1 [==============================] - 0s 57ms/step
# ISIC_6164865.jpg: Predicted class: Benign
# Probability: 0.37
# 1/1 [==============================] - 0s 69ms/step
# ISIC_8294494.jpg: Predicted class: Benign
# Probability: 0.38
# 1/1 [==============================] - 0s 61ms/step
# ISIC_1254895.jpg: Predicted class: Benign
# Probability: 0.17
# 1/1 [==============================] - 0s 56ms/step
# ISIC_8448528.jpg: Predicted class: Malignant
# Probability: 0.70
# 1/1 [==============================] - 0s 57ms/step
# ISIC_7965714.jpg: Predicted class: Benign
# Probability: 0.31
# 1/1 [==============================] - 0s 96ms/step
# ISIC_3528123.jpg: Predicted class: Benign
# Probability: 0.15
# 1/1 [==============================] - 0s 96ms/step
# ISIC_8860494.jpg: Predicted class: Benign
# Probability: 0.05
# 1/1 [==============================] - 0s 80ms/step
# ISIC_2720185.jpg: Predicted class: Benign
# Probability: 0.10
# 1/1 [==============================] - 0s 57ms/step
# ISIC_3350366.jpg: Predicted class: Benign
# Probability: 0.11
# 1/1 [==============================] - 0s 60ms/step
# ISIC_3427395.jpg: Predicted class: Benign
# Probability: 0.22
# 1/1 [==============================] - 0s 60ms/step
# ISIC_8688992.jpg: Predicted class: Benign
# Probability: 0.19
# 1/1 [==============================] - 0s 56ms/step
# ISIC_4654442.jpg: Predicted class: Benign
# Probability: 0.33
# 1/1 [==============================] - 0s 56ms/step
# ISIC_9019049.jpg: Predicted class: Benign
# Probability: 0.16
# 1/1 [==============================] - 0s 60ms/step
# ISIC_6056861.jpg: Predicted class: Malignant
# Probability: 0.53
# 1/1 [==============================] - 0s 92ms/step
# ISIC_7838806.jpg: Predicted class: Benign
# Probability: 0.24
# 1/1 [==============================] - 0s 109ms/step
# ISIC_3101113.jpg: Predicted class: Benign
# Probability: 0.44
# 1/1 [==============================] - 0s 62ms/step
# ISIC_6779189.jpg: Predicted class: Benign
# Probability: 0.20
# 1/1 [==============================] - 0s 69ms/step
# ISIC_5064265.jpg: Predicted class: Benign
# Probability: 0.03
# 1/1 [==============================] - 0s 57ms/step
# ISIC_9391523.jpg: Predicted class: Benign
# Probability: 0.36
# 1/1 [==============================] - 0s 58ms/step
# ISIC_2398530.jpg: Predicted class: Benign
# Probability: 0.32
# 1/1 [==============================] - 0s 70ms/step
# ISIC_1713289.jpg: Predicted class: Malignant
# Probability: 0.60
# 1/1 [==============================] - 0s 60ms/step
# ISIC_5106017.jpg: Predicted class: Benign
# Probability: 0.05
# 1/1 [==============================] - 0s 60ms/step
# ISIC_6627425.jpg: Predicted class: Benign
# Probability: 0.44
# 1/1 [==============================] - 0s 92ms/step
# ISIC_4669952.jpg: Predicted class: Benign
# Probability: 0.45
# 1/1 [==============================] - 0s 100ms/step
# ISIC_5049288.jpg: Predicted class: Malignant
# Probability: 0.68
# 1/1 [==============================] - 0s 57ms/step
# ISIC_9151417.jpg: Predicted class: Benign
# Probability: 0.02
# 1/1 [==============================] - 0s 59ms/step
# ISIC_4389340.jpg: Predicted class: Benign
# Probability: 0.20
# 1/1 [==============================] - 0s 60ms/step
# ISIC_2882963.jpg: Predicted class: Benign
# Probability: 0.38
# 1/1 [==============================] - 0s 56ms/step
# ISIC_6024316.jpg: Predicted class: Benign
# Probability: 0.10
# 1/1 [==============================] - 0s 59ms/step
# ISIC_4693252.jpg: Predicted class: Benign
# Probability: 0.50
# 1/1 [==============================] - 0s 57ms/step
# ISIC_5156251.jpg: Predicted class: Benign
# Probability: 0.42
# 1/1 [==============================] - 0s 58ms/step
# ISIC_4296526.jpg: Predicted class: Malignant
# Probability: 0.89
# 1/1 [==============================] - 0s 58ms/step
# ISIC_9135940.jpg: Predicted class: Benign
# Probability: 0.27
# 1/1 [==============================] - 0s 64ms/step
# ISIC_7511758.jpg: Predicted class: Benign
# Probability: 0.01
# 1/1 [==============================] - 0s 62ms/step
# ISIC_3985101.jpg: Predicted class: Benign
# Probability: 0.03
# 1/1 [==============================] - 0s 57ms/step
# ISIC_9415347.jpg: Predicted class: Benign
# Probability: 0.29
# 1/1 [==============================] - 0s 96ms/step
# ISIC_5283814.jpg: Predicted class: Malignant
# Probability: 0.85
# 1/1 [==============================] - 0s 101ms/step
# ISIC_2404209.jpg: Predicted class: Benign
# Probability: 0.38
# 1/1 [==============================] - 0s 57ms/step
# ISIC_2922356.jpg: Predicted class: Benign
# Probability: 0.08
# 1/1 [==============================] - 0s 58ms/step
# ISIC_6556202.jpg: Predicted class: Benign
# Probability: 0.44
# 1/1 [==============================] - 0s 76ms/step
# ISIC_3689148.jpg: Predicted class: Benign
# Probability: 0.35
# 1/1 [==============================] - 0s 57ms/step
# ISIC_7373877.jpg: Predicted class: Benign
# Probability: 0.03
# 1/1 [==============================] - 0s 59ms/step
# ISIC_3560802.jpg: Predicted class: Malignant
# Probability: 0.55
# 1/1 [==============================] - 0s 60ms/step
# ISIC_7212600.jpg: Predicted class: Benign
# Probability: 0.24
# 1/1 [==============================] - 0s 57ms/step
# ISIC_8390230.jpg: Predicted class: Benign
# Probability: 0.27
# 1/1 [==============================] - 0s 56ms/step
# ISIC_5519153.jpg: Predicted class: Malignant
# Probability: 0.74
# 1/1 [==============================] - 0s 91ms/step
# ISIC_3738610.jpg: Predicted class: Benign
# Probability: 0.01
# 1/1 [==============================] - 0s 93ms/step
# ISIC_2552351.jpg: Predicted class: Malignant
# Probability: 0.84
# 1/1 [==============================] - 0s 92ms/step
# ISIC_2705044.jpg: Predicted class: Benign
# Probability: 0.02
# 1/1 [==============================] - 0s 68ms/step
# ISIC_1872208.jpg: Predicted class: Malignant
# Probability: 0.89
# 1/1 [==============================] - 0s 64ms/step
# ISIC_3989338.jpg: Predicted class: Malignant
# Probability: 0.56
# 1/1 [==============================] - 0s 56ms/step
# ISIC_5082705.jpg: Predicted class: Malignant
# Probability: 0.65
# 1/1 [==============================] - 0s 57ms/step
# ISIC_2178381.jpg: Predicted class: Benign
# Probability: 0.06
# 1/1 [==============================] - 0s 61ms/step
# ISIC_3304326.jpg: Predicted class: Benign
# Probability: 0.39
# 1/1 [==============================] - 0s 59ms/step
# ISIC_2661607.jpg: Predicted class: Malignant
# Probability: 0.83
# 1/1 [==============================] - 0s 65ms/step
# ISIC_9415087.jpg: Predicted class: Benign
# Probability: 0.30
# 1/1 [==============================] - 0s 96ms/step
# ISIC_2722040.jpg: Predicted class: Benign
# Probability: 0.07
# 1/1 [==============================] - 0s 90ms/step
# ISIC_9181340.jpg: Predicted class: Benign
# Probability: 0.45
# 1/1 [==============================] - 0s 90ms/step
# ISIC_4965292.jpg: Predicted class: Malignant
# Probability: 0.58
# 1/1 [==============================] - 0s 64ms/step
# ISIC_9716246.jpg: Predicted class: Benign
# Probability: 0.04
# 1/1 [==============================] - 0s 58ms/step
# ISIC_7506745.jpg: Predicted class: Benign
# Probability: 0.16
# 1/1 [==============================] - 0s 54ms/step
# ISIC_8969962.jpg: Predicted class: Benign
# Probability: 0.13
# 1/1 [==============================] - 0s 61ms/step
# ISIC_3775513.jpg: Predicted class: Malignant
# Probability: 0.50
# 1/1 [==============================] - 0s 59ms/step
# ISIC_2269465.jpg: Predicted class: Benign
# Probability: 0.16
# 1/1 [==============================] - 0s 62ms/step
# ISIC_8472353.jpg: Predicted class: Benign
# Probability: 0.04
# 1/1 [==============================] - 0s 57ms/step
# ISIC_4630161.jpg: Predicted class: Benign
# Probability: 0.44
# 1/1 [==============================] - 0s 57ms/step
# ISIC_8655348.jpg: Predicted class: Benign
# Probability: 0.18
# 1/1 [==============================] - 0s 59ms/step
# ISIC_6782432.jpg: Predicted class: Benign
# Probability: 0.05
# 1/1 [==============================] - 0s 63ms/step
# ISIC_5820450.jpg: Predicted class: Benign
# Probability: 0.16
# 1/1 [==============================] - 0s 90ms/step
# ISIC_0995436.jpg: Predicted class: Malignant
# Probability: 0.85
# 1/1 [==============================] - 0s 89ms/step
# ISIC_1464049.jpg: Predicted class: Benign
# Probability: 0.09
# 1/1 [==============================] - 0s 99ms/step
# ISIC_7471956.jpg: Predicted class: Malignant
# Probability: 0.77
# 1/1 [==============================] - 0s 60ms/step
# ISIC_8083476.jpg: Predicted class: Benign
# Probability: 0.45
# 1/1 [==============================] - 0s 56ms/step
# ISIC_9660608.jpg: Predicted class: Malignant
# Probability: 0.81
# 1/1 [==============================] - 0s 61ms/step
# ISIC_2941121.jpg: Predicted class: Malignant
# Probability: 0.52
# 1/1 [==============================] - 0s 59ms/step
# ISIC_8509539.jpg: Predicted class: Malignant
# Probability: 0.64
# 1/1 [==============================] - 0s 58ms/step
# ISIC_0958029.jpg: Predicted class: Benign
# Probability: 0.21
# 1/1 [==============================] - 0s 58ms/step
# ISIC_2287032.jpg: Predicted class: Benign
# Probability: 0.24
# 1/1 [==============================] - 0s 59ms/step
# ISIC_3963047.jpg: Predicted class: Benign
# Probability: 0.47
# 1/1 [==============================] - 0s 56ms/step
# ISIC_5464296.jpg: Predicted class: Benign
# Probability: 0.08
# 1/1 [==============================] - 0s 61ms/step
# ISIC_0497721.jpg: Predicted class: Benign
# Probability: 0.06
# 1/1 [==============================] - 0s 56ms/step
# ISIC_5944731.jpg: Predicted class: Malignant
# Probability: 0.81
# 1/1 [==============================] - 0s 86ms/step
# ISIC_4837220.jpg: Predicted class: Benign
# Probability: 0.10
# 1/1 [==============================] - 0s 99ms/step
# ISIC_8817936.jpg: Predicted class: Benign
# Probability: 0.02
# 1/1 [==============================] - 0s 90ms/step
# ISIC_0894646.jpg: Predicted class: Malignant
# Probability: 0.54
# 1/1 [==============================] - 0s 93ms/step
# ISIC_2262489.jpg: Predicted class: Malignant
# Probability: 0.54
# 1/1 [==============================] - 0s 63ms/step
# ISIC_1049919.jpg: Predicted class: Malignant
# Probability: 0.67
# 1/1 [==============================] - 0s 60ms/step
# ISIC_1268457.jpg: Predicted class: Malignant
# Probability: 0.95
# 1/1 [==============================] - 0s 56ms/step
# ISIC_6631138.jpg: Predicted class: Benign
# Probability: 0.05
# 1/1 [==============================] - 0s 66ms/step
# ISIC_0700201.jpg: Predicted class: Benign
# Probability: 0.12
# 1/1 [==============================] - 0s 58ms/step
# ISIC_1979791.jpg: Predicted class: Benign
# Probability: 0.43
# 1/1 [==============================] - 0s 56ms/step
# ISIC_4394742.jpg: Predicted class: Benign
# Probability: 0.44
# 1/1 [==============================] - 0s 74ms/step
# ISIC_9374581.jpg: Predicted class: Benign
# Probability: 0.22
# 1/1 [==============================] - 0s 94ms/step
# ISIC_1514638.jpg: Predicted class: Malignant
# Probability: 0.83
# 1/1 [==============================] - 0s 108ms/step
# ISIC_8190844.jpg: Predicted class: Benign
# Probability: 0.01
# 1/1 [==============================] - 0s 103ms/step
# ISIC_6717898.jpg: Predicted class: Malignant
# Probability: 0.66
# 1/1 [==============================] - 0s 57ms/step
# ISIC_4755685.jpg: Predicted class: Benign
# Probability: 0.07
# 1/1 [==============================] - 0s 58ms/step
# ISIC_8525942.jpg: Predicted class: Malignant
# Probability: 0.78
# 1/1 [==============================] - 0s 60ms/step
# ISIC_0804023.jpg: Predicted class: Benign
# Probability: 0.02
# 1/1 [==============================] - 0s 60ms/step
# ISIC_5249429.jpg: Predicted class: Benign
# Probability: 0.50
# 1/1 [==============================] - 0s 57ms/step
# ISIC_5231939.jpg: Predicted class: Benign
# Probability: 0.23
# 1/1 [==============================] - 0s 59ms/step
# ISIC_2133395.jpg: Predicted class: Benign
# Probability: 0.37
# 1/1 [==============================] - 0s 60ms/step
# ISIC_6903971.jpg: Predicted class: Benign
# Probability: 0.15
# 1/1 [==============================] - 0s 61ms/step
# ISIC_3916591.jpg: Predicted class: Malignant
# Probability: 0.90
# 1/1 [==============================] - 0s 101ms/step
# ISIC_9005237.jpg: Predicted class: Malignant
# Probability: 0.60
# 1/1 [==============================] - 0s 93ms/step
# ISIC_1933590.jpg: Predicted class: Benign
# Probability: 0.16
# 1/1 [==============================] - 0s 68ms/step
# ISIC_0090283.jpg: Predicted class: Benign
# Probability: 0.14
# 1/1 [==============================] - 0s 57ms/step
# ISIC_8789564.jpg: Predicted class: Benign
# Probability: 0.38
# 1/1 [==============================] - 0s 59ms/step
# ISIC_8679128.jpg: Predicted class: Benign
# Probability: 0.33
# 1/1 [==============================] - 0s 60ms/step
# ISIC_9634301.jpg: Predicted class: Benign
# Probability: 0.04
# 1/1 [==============================] - 0s 61ms/step
# ISIC_9228022.jpg: Predicted class: Malignant
# Probability: 0.55
# 1/1 [==============================] - 0s 58ms/step
# ISIC_0368696.jpg: Predicted class: Malignant
# Probability: 0.77
# 1/1 [==============================] - 0s 60ms/step
# ISIC_9146470.jpg: Predicted class: Malignant
# Probability: 0.71
# 1/1 [==============================] - 0s 57ms/step
# ISIC_6154102.jpg: Predicted class: Benign
# Probability: 0.46
# 1/1 [==============================] - 0s 90ms/step
# ISIC_9354346.jpg: Predicted class: Benign
# Probability: 0.03
# 1/1 [==============================] - 0s 83ms/step
# ISIC_3207493.jpg: Predicted class: Benign
# Probability: 0.02
# 1/1 [==============================] - 0s 57ms/step
# ISIC_6591551.jpg: Predicted class: Benign
# Probability: 0.15
# 1/1 [==============================] - 0s 58ms/step
# ISIC_0969096.jpg: Predicted class: Malignant
# Probability: 0.66
# 1/1 [==============================] - 0s 66ms/step
# ISIC_1706501.jpg: Predicted class: Malignant
# Probability: 0.51
# 1/1 [==============================] - 0s 62ms/step
# ISIC_0348342.jpg: Predicted class: Benign
# Probability: 0.03
# 1/1 [==============================] - 0s 58ms/step
# ISIC_2121807.jpg: Predicted class: Benign
# Probability: 0.26
# 1/1 [==============================] - 0s 63ms/step
# ISIC_2288144.jpg: Predicted class: Malignant
# Probability: 0.51
# 1/1 [==============================] - 0s 58ms/step
# ISIC_3908014.jpg: Predicted class: Benign
# Probability: 0.10
# 1/1 [==============================] - 0s 60ms/step
# ISIC_4327951.jpg: Predicted class: Benign
# Probability: 0.05
# 1/1 [==============================] - 0s 59ms/step
# ISIC_0246008.jpg: Predicted class: Benign
# Probability: 0.16
# 1/1 [==============================] - 0s 99ms/step
# ISIC_7825185.jpg: Predicted class: Malignant
# Probability: 0.93
# 1/1 [==============================] - 0s 117ms/step
# ISIC_4416545.jpg: Predicted class: Malignant
# Probability: 0.84
# 1/1 [==============================] - 0s 96ms/step
# ISIC_5320315.jpg: Predicted class: Benign
# Probability: 0.13
# 1/1 [==============================] - 0s 96ms/step
# ISIC_5784853.jpg: Predicted class: Malignant
# Probability: 0.58
# 1/1 [==============================] - 0s 68ms/step
# ISIC_5690889.jpg: Predicted class: Malignant
# Probability: 0.75
# 1/1 [==============================] - 0s 63ms/step
# ISIC_8677397.jpg: Predicted class: Malignant
# Probability: 0.94
